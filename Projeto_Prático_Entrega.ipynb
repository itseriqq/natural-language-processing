# %% [markdown]
# <a href="https://colab.research.google.com/github/itseriqq/natural-language-processing/blob/main/Projeto_Pr%C3%A1tico_Vers%C3%A3o_2_PLN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2025-Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **PROJETO PRÁTICO** [LangChain + Grandes Modelos de Linguagem]

# %% [markdown]
# O **PROJETO PRÁTICO** deve ser feito utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook armazenado no Google Drive e o link de um repositório no GitHub devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/D4gLqP1iGgyn2hbH8
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **07/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `Erick Augusto Silva Pereira - RA: 11202130310`
#
# **Integrante 02:**
#
# `Victor Ravazio de Lima - RA: 11201920941`

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*).

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: Gemini (Modelo 2.5-Flash)
#
# >
#
# **Link para a documentação oficial**: https://ai.google.dev/gemini-api/docs/

# %% [markdown]
# ### **API (Opcional)**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
# **API**: TwitterApi.io
#
# **Site oficial**: https://twitterapi.io/
#
# **Link para a documentação oficial**: https://docs.twitterapi.io/introduction

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, DUAS técnicas de PLN. As técnicas podem ser aplicada em qualquer córpus obtido a partir de uma **API** ou a partir de uma página Web.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1iIUZcwnywO7RuF6VEJ8Rx9NDT1cwteyvsnkhYr0NWtU/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   **Classificação de Textos**
# *   **Análise de Sentimentos**
# *   **Detecção de Emoções**
# *   **Extração de Palavras-chave**
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
# >
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os seguintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API** ou **Página Web**.
#
# * Projeto disponível no Github.
#
# * Apresentação (5 a 10 minutos).
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# ![capa_apresentação.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# *   **Análise de Sentimentos**
# *   **Detecção de Emoções**
# *   **Classificação de Textos**
# *   **Extração de Palavras-chave**
#
# LLM: Gemini 2.5-Flash
#
# API: TwitterAPI.io

# %% [markdown]
# # Introdução
# Nosso primeiro objetivo era analisar os sentimentos detectados em diferentes espectros políticos divergentes envolvendo um mesmo acontecimento.
#
# No caso, utilizamos respostas a tweets de figuras influentes representativas de determinado campo político, comentando o assassinato de Charlie Kirk:

# %% [markdown]
# ![manchete.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tweet_elon.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tweet_tiago.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tweet_ian.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Tweet "coringa":
#
# ![tweet_don.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Capturando as respostas de tweets com TwitterAPI
#
# Vamos utilizar a TwitterAPI para coletar as respostas do tweet especificado e salva-lás em um array de textos, salvando também em um arquivo .json para utilizar posteriormente e evitar consultas desnecessárias.

# %%
#@title Inicializando

import requests
import time
import json
from google.colab import userdata

api_key = userdata.get('twitterApi2')

headers = {
    'X-API-Key': api_key,
    'Accept': 'application/json',
}

# %%
#@title Função de captura de respostas na API

def capturar_respostas(tweet_id, lista, page_count = 0, cursor = "", max_pages=2):
  while page_count < max_pages:
    # monta URL incluindo cursor (query param para buscar mais dados) só se não for vazio
    if cursor:
        url = f'https://api.twitterapi.io/twitter/tweet/replies?tweetId={tweet_id}&cursor={cursor}'
    else:
        url = f'https://api.twitterapi.io/twitter/tweet/replies?tweetId={tweet_id}'

    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f'Erro {response.status_code}: {response.text}')
        break

    data = response.json()
    tweets = data.get("tweets", [])
    textos = [tweet["text"] for tweet in tweets]
    lista.extend(textos)

    page_count += 1

    if data.get("has_next_page", False):
        cursor = data.get("next_cursor", "")
        time.sleep(6)  # aguarda 6 segundos antes da próxima requisição para burlar os 5 segundos de api limit q eles tem
    else:
        break

# %%
#@title Função que salva as respostas em um arquivo .json

def salvar_json(lista, sufixo=""):
    # Monta o nome do arquivo dinamicamente
    filename = f"replies_{sufixo}.json" if sufixo else "replies.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(lista, f, ensure_ascii=False, indent=2)

# %%
#@title Carregando o conteúdo de um arquivo .json na lista

def carregar_json(lista, sufixo=""):
    filename = f"replies_{sufixo}.json" if sufixo else "replies.json"
    with open(filename, "r", encoding="utf-8") as f:
        dados = json.load(f)
    lista.extend(dados)

# %%
#@title Função que imprime os tweets da lista
def imprimir_lista(lista):
  print(f"Quantidade total de tweets: {len(lista)}")
  for i, texto in enumerate(lista, 1):
      print(f"Tweet {i}: {texto}\n")

# %%
#@title Definição das listas e tweetsIds que serão utilizados

all_texts_1, all_texts_2, all_texts_3, all_texts_4 = [], [], [], []
tweet_id_1, tweet_id_2, tweet_id_3, tweet_id_4  = '1965860002545152203', '1965915119973699902', '1965898635293683717', '1990538237979574552'
# Elon Musk, Tiago Santineli, Ian Neves, Don Elece

# %% [markdown]
# Utilizando as funções definidas para capturar as informações com a API e salvar os resultados em arquivos .json.

# %%
capturar_respostas(tweet_id_1, all_texts_1)
salvar_json(all_texts_1,'1')

# %%
capturar_respostas(tweet_id_2, all_texts_2)
salvar_json(all_texts_2,'2')

# %%
capturar_respostas(tweet_id_3, all_texts_3)
salvar_json(all_texts_3,'3')

# %%
capturar_respostas(tweet_id_4, all_texts_4)
salvar_json(all_texts_4,'4')

# %% [markdown]
# Após feita a coleta dos dados pela API e estes serem salvos em seus respectivos arquivos .json, podemos utilizar apenas os seguintes códigos para apenas carregar esses arquivos para a análise da LLM, não gastando tokens desnecessários em toda execução da workspace.

# %%
# @title Elon Musk
carregar_json(all_texts_1, '1')
imprimir_lista(all_texts_1)
# Out:
# Quantidade total de tweets: 33
# Tweet 1: @PookiesParadise @GoldBoy542524 @elonmusk Idk pretty sure right wingers was pushin for death on liberal ppl too at some point bc of their views, what changed https://t.co/HPHNbOXeux
#
# Tweet 2: @elonmusk Whoever the shooter may be, the only good thing they managed to do was save us from a president Kirk in 2040.
#
# Tweet 3: @elonmusk What is the TRUTH about his death?
#
# Tweet 4: @FoundersEcho @mandala_mandy @elonmusk You have a problem with God's will?
#
# Satanist
#
# Tweet 5: @elonmusk @Davidharris_9 😭
#
# Tweet 6: @elonmusk @fatherdoge4207 He died instantly assclown!
#
# Tweet 7: @Shadow_Vx88 @PookiesParadise @elonmusk Low IQ opinion.
#
# Now turn to the left
#
# Tweet 8: @elonmusk It was not comparable with life. Too much damage.😢 so full of life and promise. Amazing young man. Gone in an instant. Irreplaceable 🤦🏼‍♀️ 💔
#
# Tweet 9: @JimEagleUC @PookiesParadise @elonmusk if ur logic is correct, everyone and I mean everyone would die, there will never be one thing that every human being can agree upon. Not to mention, that every person has a different idea of what's right and what's wrong, End topic.
#
# Tweet 10: @elonmusk @saxsonmusk5 😭😭😭🙏🏻✨
#
# Tweet 11: @elonmusk Much more better
#
# Tweet 12: @elonmusk @youngchris_0852 Sorry !
#
# Tweet 13: @JacksonDann @elonmusk Well think about context first before you consider whether or not it's true perhaps
#
# Tweet 14: @elonmusk @saxsonmusk5 🥺we will forever be changed by his goodness. May his name always be remembered for the love of God and Jesus he proudly proclaimed ❤️
#
# Tweet 15: @dallaswright71 @Emilia__writes @elonmusk Well he also wasn’t a democrat😭
#
# Tweet 16: @Deveqv_2 @jessejacobsof @rax13gaming @naifvsexpert @elonmusk They are doing that thing again where they pretend the parties didn’t switch.
#
# Tweet 17: @rax13gaming @naifvsexpert @elonmusk Love how y’all pretend the parties didn’t switch. Most of the political violence in your country comes from the far right. Stop pretending you’re still the party of Lincoln 💀
#
# Tweet 18: @elonmusk @elonspacexms A 30-06 would shatter a 1000lb cow leg, with stronger bones. I shot my dad’s once &amp; it put me a foot back on the ground. Now truthfully it souls Oswald-ish to me. (That would be back in the 60’s)
#
# Tweet 19: @TrumpUpdateHQ @elonmusk If someone could turn back time,how many misfortunes could be fixed !😥
#
# A piece of advice:
# 👉Prevention is the mother of wisdom,and one step before fatality!
# 👉Fatality has no remorse,pauses or empathy,it always looks for opportunities.
#
# God bless you🙏❤️
#
# RIP Charlie Kirk🙏🌹
#
# Tweet 20: @elonmusk @tesla_ceo74 If someone could turn back time,how many misfortunes could be fixed !😥
#
# A piece of advice:
# 👉Prevention is the mother of wisdom,and one step before fatality!
# 👉Fatality has no remorse,pauses or empathy, it always looks for opportunities.
#
# God bless you 🙏
# RIP Charlie Kirk 🙏🌹
#
# Tweet 21: @DavidPuddy212 @elonmusk why did u cut off what he said right after in rogan
#
# Tweet 22: @CoSatoshi821 @Mathamphetamime @SourAlphabetic1 @realdeepakterra @elonmusk brother your lot was calling the Palestinians terrorists after October 7th because they did it to white people, while ignoring the terrorism Israelis have been doing to them since 1948. my tweet is literally correct, so was my fascism tweet.
#
# Tweet 23: @edelweiss_kat @Mathamphetamime @SourAlphabetic1 @realdeepakterra @elonmusk wow, so clever.
#
# Tweet 24: @CoSatoshi821 @Mathamphetamime @SourAlphabetic1 @realdeepakterra @elonmusk "terrorist" just means anything you disagree with. you are a white nationalist, and you should be treated as such.
#
# Tweet 25: @edelweiss_kat @Mathamphetamime @SourAlphabetic1 @realdeepakterra @elonmusk "material harm" just means anything you disagree with. you are a terrorist, and you should be treated as such.
#
# Tweet 26: @Mathamphetamime @SourAlphabetic1 @CoSatoshi821 @realdeepakterra @elonmusk not how the body works, sorry! even if you're decapitated, you retain consciousness for several seconds.
#
# also, no I don't. but I celebrate when people who cause material harm die, yes. as would most people.
#
# Tweet 27: @edelweiss_kat @SourAlphabetic1 @CoSatoshi821 @realdeepakterra @elonmusk I realize that you pleasure yourself thinking about human suffering, because that's what communist subhumans do, but as someone who has put bullets into a significant number of living creatures I can tell you he was dead before he fell off the chair.
#
# Tweet 28: @Mathamphetamime @SourAlphabetic1 @CoSatoshi821 @realdeepakterra @elonmusk Lmao no, he was alive for a long while, and I hope he felt it good.
#
# Tweet 29: @elonmusk I zas
#
# Tweet 30: @elonmusk @saxsonmusk5 Thanks a lot for this post @elonmusk. I see it only now. This was awful. Stay safe.
# Most Highi is with all of you.🙏🏼❤️
#
# Tweet 31: @rcodydeal @bmaretheprize @elonmusk https://t.co/P1Ggipkfk7
#
# Tweet 32: @xUnknownColorX @touchedbyosiris @elonmusk N what?
#
# Tweet 33: @test8182614 @bmaretheprize @elonmusk https://t.co/bpSthWtFoG

# %%
# @title Tiago Santineli
carregar_json(all_texts_2, '2')
imprimir_lista(all_texts_2)
# Out:
# Quantidade total de tweets: 40
# Tweet 1: @graziela_galli @SaxGuga @tiagosantineli @SecRubio @SecState @DeputySecState Não tem nada pra fazer não militante estrangeira? Vai ler pra cego ou fazer uma doação pra caridade
#
# Tweet 2: @carluxo1921 @tiagosantineli Tem a puta Gil tbm KKKKKKKKKKK
#
# Tweet 3: @tiagosantineli sua vida é tão triste assim mano?
#
# Tweet 4: @ZA_WWARUDO @tiagosantineli O mesmo que disse que se a filha de dez anos fosse estuprada, ele forçaria ela a manter o bebê e faria ela passar pelo parto? Talvez tenha sido um livramento! 🫩
#
# Tweet 5: @Leaah_lin_ @tiagosantineli começou oque
#
# Tweet 6: @graziela_galli @tiagosantineli @SecRubio @DeputySecState Hi, @SecRubio and @DeputySecState! I'm from Brazil. Keep your 3 Pages constitution, all that "WE THE PEOPLE..." crap and put up your a$$.
#
# @graziela_galli, você tem algum problema com a minha liberdade de expressão? Vai dizer que eu ultrapassei o limite do humor? Hahahahaha...
#
# Tweet 7: @sdsyv1 @ZA_WWARUDO @tiagosantineli c é bem machão na internet né
#
# Tweet 8: @ZA_WWARUDO @tiagosantineli Começou já kkkk
#
# Tweet 9: @Matheusol230407 @tiagosantineli Se for chorar manda áudio, seu cuzão chorão!
#
# Tweet 10: @tiagosantineli Cabeça de ozempic
#
# Tweet 11: @saindodenarnia1 @ZA_WWARUDO @tiagosantineli O assassino fascista ainda tá vivo
#
# Tweet 12: @tiagosantineli ai scrrrr
#
# Tweet 13: @DoIIIisa @tiagosantineli Do que eu vi do Nikolas, ele simplesmente apontou q esse pessoal n ia ter misericórdia de qm n fosse do msm lado q eles e por isso deviam ser reconhecidos como inimigos, n vi nada sobre ter empatia
#
# Tweet 14: @EveMs0 @DoIIIisa @tiagosantineli https://t.co/obqDvZxSuz
#
# Tweet 15: @EveMs0 @DoIIIisa @tiagosantineli Aqui https://t.co/jAGdKygdIc
#
# Tweet 16: @EveMs0 @DoIIIisa @tiagosantineli Saiu no jornal, vê lá deixa e procurar e linkar aqui pera ai
#
# Tweet 17: @graziela_galli @tiagosantineli @SecRubio @SecState @DeputySecState https://t.co/zTgjf6Zqv7
#
# Tweet 18: @Convertor717 @deekvlt @tiagosantineli https://t.co/UQUlOF6end
#
# Tweet 19: @sandrazarp @tiagosantineli Veia vai aquietar o fogo do teu cu
#
# Tweet 20: @rakelzinha_dias @mascatora @tiagosantineli 35 anos tá chegando hein, melhor preparar a cordinha ó molestado pelo tio
#
# Tweet 21: @Kaiser11131 @tiagosantineli Calma aí ó cpzeiro
#
# Tweet 22: @pedrobeldum @MaranaoSilva @tiagosantineli Você foi estuprado pelo tio, com certeza
#
# Tweet 23: @ZA_WWARUDO @tiagosantineli Só recebeu o que pregava pra família dos outros. Besta é quem ainda se compadece.
#
# Tweet 24: @tiagosantineli E a Preta Gil que peidou e explodiu?
#
# Tweet 25: @syoles86 @deekvlt @tiagosantineli Aaaaaaa que susto Preta Gil
#
# Tweet 26: @graziela_galli @tiagosantineli @SecRubio @DeputySecState @SecState https://t.co/EFUidIpVuO
#
# Tweet 27: @graziela_galli @tiagosantineli @DeputySecState @SecState @SecRubio Pô, marcou os caras num post que nem era o meu melhor https://t.co/FbGfpf3RH5
#
# Tweet 28: @Hermesmes457 @tiagosantineli obvio q eu to indignado man. Todo comentário que ta falando merda é motivo pra falar palavrão
# Só melhore man, e enxergue como uma família q perdeu seu pai
#
# Tweet 29: @EveMs0 @DoIIIisa @tiagosantineli É meio evidente, o cara estava disposto a ser convencido e a dialogar, todo o "mal" q ele fez se resume a ter uma opinião e argumentar por ela, isso n se compara a uma pessoa q usufrui do mal dos outros, cujo trabalho se resume a se aproveitar de toda uma nação
#
# Tweet 30: @tiagosantineli Só fala merda na net sua putinha do krl
#
# Tweet 31: @DoIIIisa @tiagosantineli Sendo sincero, queria um exemplo disso, pq oq mais vejo é o pessoal q zombou de um tentar revidar qnd zombam do outro, n clamar por empatia.
#
# Tweet 32: @ZA_WWARUDO @tiagosantineli As filhas podem ter a chance de arrumar um pai melhor e a mulher dar pra um cara mais bonito kkkkk
#
# Tweet 33: @graziela_galli @tiagosantineli @SecRubio @SecState @DeputySecState Pega a doida https://t.co/HwoqXkCh3F
#
# Tweet 34: @tiagosantineli Ele é mirolha mesmo, acerta seu furico no escuro
#
# Tweet 35: @Hermesmes457 @tiagosantineli bizarro ler isso
#
# Tweet 36: @PedroSovietbear @tiagosantineli nunca vi ele fazendo piada c esse tipo de coisa na real, só mostrando a opinião (que eu condeno tb).
# Mas o cara era pai mano, para de preocupar c ele. Morreu porra.
#
# Tweet 37: @sdsyv1 @tiagosantineli crianças cara, crianças
#
# Tweet 38: @sdsyv1 @tiagosantineli paia em
#
# Tweet 39: @taradafilo @tiagosantineli q?
#
# Tweet 40: @dsrklind @tiagosantineli nem sou de direita kkkkkkkkkkk

# %%
# @title Ian Neves

carregar_json(all_texts_3, '3')
imprimir_lista(all_texts_3)
# Out:
# Quantidade total de tweets: 40
# Tweet 1: @leoodoritos @ianfneves ELE defendeu que execuções de pena de morte fossem públicas, televisionadas e até patrocinadas pela Coca-Cola, e que crianças deveriam assistir
#
# EU particularmente acho paia pra krl alguém morrer assim
#
# é ELE quem acha ok, quem sou eu e quem é vc pra achar errado
#
# Tweet 2: @Rafha7x @ianfneves kkkkkkkk O Xingador.
#
# Tweet 3: @leoodoritos @ianfneves O beta entrou em parafuso pra defender o charlie pescocinho https://t.co/wtlfNVRXAQ
#
# Tweet 4: @PalmeirasFort @leoodoritos @ianfneves O Brasil segue sendo líder em assassinatos e aqui a arma é liberada?
#
# Tweet 5: @GoblinWasabi @ianfneves como?fiquei curioso, o seu caráter varia de acordo com o suposto caráter de outro?
#
# Tweet 6: @GabZozimo @ianfneves além do mais, você não falou nada sobre sentir pena dele, você não sente pena de um inocente ser assassinado?não sente pena da esposa e da filha? não quero te desmoralizar, é só uma duvida, porque eu acredito que todos nós, desde adão ate o último a nascer, somos podres iguais.
#
# Tweet 7: @GabZozimo @ianfneves nao usei ad hominem, pelo contrário, te achei inteligente, vi teu perfil. so queria que vc me explicasse o termo que usou e como ele se enquadra em kirk. um mesmo termo pode ter significados diferentes pra duas pessoas não acha?
#
# Tweet 8: @xfrangobacon @ianfneves sabe o porquê de eu não entrar no merito moral?pq todos nos somos a mesma merda que ele, nunca teve um misero ser humano bom na terra, o unico que era um pouco mais que humano, a gente conseguiu a proeza de crucificar ele, e assim foi feito, pra gente não ter o que merece:inferno
# Tweet 27: @MesquitaGe68901 @ianfneves ele foi assassinado, e sim, por suas posições políticas. nisso concordamos, agora, quem pode legitimar um assassino?acho que assassinato é pior do que tudo que vc citou aí. não acho que ninguém merece morrer pelas seus princípios, por mais que descordemos deles.
#
# Tweet 28: @LaSavane_ @ianfneves ah, ele tá bem, se desencolvendo, tenho 18 anos e 122 de QI hahaha. se seu entretenimento é chamar pessoas de burras na internet, deveria rever sua perspectiva sobre a própria inteligência, sabe, tem estudos sobre esse comportamento
#
# Tweet 29: @ComunaCassi @ianfneves você sabe o que é essa característica?por que ele se enquadra nela? e por que isso tira a humanidade dele? responde essas 3 e podemos discutir um pouco
#
# Tweet 30: @mathenrikk @ianfneves por que a agressividade? levantei uma questão, e afirmo que acho errado banalizar a morte de qualquer humano, você não acha?
#
# Tweet 31: @lucytokcf @ianfneves eu nao sei se fez, e se fez é errado. e banalizar o dele também é, se você não gostava dele, e, fazer o que ele teoricamente fazia, te torna pior que ele
#
# Tweet 32: @D4nGreg @ianfneves concordo com você, infelizmente concordo, hoje temos que dobrar o cuidado com nossas posições porque os adversários politicos, que deveriam estar no campo das ideias, hoje, são ameaças a vida, tanto pra um lado quanto para o outro
#
# Tweet 33: @SUEZ_ZEUS_ @ianfneves vidas humanas importam, e prove que ele era isso que vc alega ser, vamos ter um debate saudável
#
# Tweet 34: @Fabricio_Braga @ianfneves era um ser vivo, e lamentaria igual se fosse o proprio ian neves o assassinado. não tenho o direito a escolher com que eu devo ou nao ter empatia, isso me tornaria um pessima homem. se você nao liga pra mortes a nao ser que sejam seus parentes, recomendaria rever seus princípios
#
# Tweet 35: @der1lein @ianfneves sua opniao sobre o carater dele nao justifica o assassinato dele, e banalizar esse crime é cruel. se cada um pudesse matar as pessoas que consideram um bosta, todos estariam mortos, nem Jesus agradou a todos, quem dira eu, voce, kirk…
#
# Tweet 36: @minimalex @ianfneves nao entendi, tenho tdah, explica
#
# Tweet 37: @Skarceci @ianfneves sim eu teria, assim como tenho das minorias, não posso escolher com quem eu tenho empatia, caso contrario eu seria um pessimo ser humano e nem um pouco cristão. mas nao me recordo de ele falar isso.
#
# Tweet 38: @cat60351 @ianfneves se cada um pudesse matar as pessoas que consideram essas características que vc citou, muita gente estaria morta. imagine que alguem ache você assim? a nossa propria opniao nao pode ser maior que o direito a vida de outra pessoa, concorda?
#
# Tweet 39: @Jonatha04864185 @ianfneves o que você quis dizer com isso? que se ele era a favor do armamento, logo, ser morto por armas torna o assassinato legitimo, que nao se pode questionar?
#
# Tweet 40: @LucioNetto4 @ianfneves porque? sabe quem acreditava que a humanidade se dividia entre posições políticas e geneticas? pois é, um cara com um bigode feio

# %%
# @title Don Elece

carregar_json(all_texts_4, '4')
imprimir_lista(all_texts_4)
# Out:
# Quantidade total de tweets: 40
# Tweet 1: @DonElece vc tem 26 anos? :0
#
# Tweet 2: @DonElece @PenseNBA Deve ser insuportável para eles escutar isso todo dia kkkkkkk pqp
#
# Tweet 3: @PenseNBA santa burrice
#
# Tweet 4: @DonElece Faz 3 anos que trabalho por conta. Também como designer.
#
# Ganhando meu dinheirinho sem precisar sair do meu quarto.
#
# Minha meta era ganhar 5 mil. Ganhei mês passado.
#
# Quase chorei.
#
# Tweet 5: @DonElece Excelente trabalho o de seus pais e o seu. Parabéns pela bela família e sucesso sempre na sua vida através da receita que te trouxe até aqui: trabalho honesto e dando nó em pingo d’água quando necessário.
#
# Tweet 6: @DonElece Eu tmb sou designer, mas nunca consegui um cliente, comecei em 2023 nessa área, vou deixar aqui as minhas artes de futebol e uma que eu fiz para a coca cola por diversão e para aperfeiçoar as minhas técnicas https://t.co/WpVIxOXUqn
#
# Tweet 7: @DonElece don, queria muito entrar nessa área, mas tenho conhecimento extremamente básico (pra não dizer 0), tem alguma recomendação de curso/professor/lugar em que eu possa aprender, claro, pra quem quer mesmo consegue se virar e achar, mas eu queria uma dica de alguém experiente na área
#
# Tweet 8: @DonElece parabéns pela conquista!
#
# Tweet 9: @DonElece Que história legal!
#
# Tweet 10: @DonElece E doido isso, inverso a isso, tenho um amigo meu que é animal para desenvolver material e super inteligente nas ideias, so que e doido. Gosta de beber e viver a vida, quer nada com nada, mó pecado, mas otimo profissional nada a ver com o assunto, so lembrei das oportunidades...
#
# Tweet 11: @DonElece ♥️♥️♥️
#
# Tweet 12: @DonElece 🥰🥰🥰🥰
#
# Tweet 13: @DonElece Quero doar um MacBook 2021 com tela quebrada mas q funciona com um monitor externo. Quem tiver interesse me avisa
#
# Tweet 14: @defcondoug @DonElece Pra um ri o outro tem que chorar paizão
#
# Tweet 15: @DonElece Pra quem trabalha no design gráfico ali fazendo arte no Canva, qual é o Mac indicado, mais custo beneficio
#
# Tweet 16: @DonElece Parabéns pelo desenvolvimento e desempenho, o trabalho devolve irmão.
#
# Tweet 17: @DonElece To com acer q só falta me implorar pra não ligar ele kkk não vejo a hora de ter um Mac 🙏
#
# Tweet 18: @DonElece Com certeza eles têm muito orgulho! Mais uma vez, parabéns!
#
# Tweet 19: @DonElece Parabens mano!!
#
# Tweet 20: @DonElece também comecei com um notebook bem fraco 1gb de ram, intel celeron, lenovo.
#
# era o que tinha e deu certo!
#
# Tweet 21: @DonElece Mto top Don, acompanho vc tem pouco tempo aqui, mas fico impressionado com seu trabalho.
#
# Só uma dúvida, vc presta serviços para várias empresas, ou tem uma única?
#
# Tweet 22: @DonElece Ter é bom, mas conquistar as coisas que sonhamos quando pequenos e que pareciam inalcançáveis é SURREAL. Parabéns 👏🏻
#
# Tweet 23: @Ricksrtl @defcondoug @DonElece https://t.co/tEbyldCLE9
#
# Tweet 24: @defcondoug @DonElece @lebrancomilgrau sempre ele na cena do crime
#
# Tweet 25: @hakunamanatta @DonElece Vai mor ❤️
#
# Tweet 26: Brigado pelo carinho nesse post, pessoal. Normalmente só tenho essa alcance quando falo alguma bobagem 😅
#
# Pra quem quiser ficar aqui e acompanhar meu trabalho, será muito bem-vindo. Hoje eu trabalho com Design no mundo corporativo, aqui no Brasil, e com alguns clubes do futebol europeu.
#
# Meu trabalho mais conhecido aqui nas redes é para o Manchester City. Posto diariamente sobre design na rede ao lado também.
#
# Estamos juntos!
#
# Tweet 27: @PenseNBA Falo pra eles todo santo dia. Somos vizinhos hoje e nos vemos diariamente. A primeira pessoa a ver foto do notebook foi meu pai, já que meu avô, pai dele, era viciado em tecnologia.
#
# A gente ficou feliz lembrando disso. Mas gosto de expor essas coisas aqui também. Já tem muita coisa ruim.
#
# Tem que celebrar as coisas boas também.
#
# Tweet 28: @DonElece Amo ler esse tipo de post, parabéns Don! 🫶🏼👏🏼👏🏼
#
# Tweet 29: @DonElece Nunca esqueça de onde vc veio e quem te apoiou pra chegar onde vc está e onde vc ainda vai conquistar. Isso te faz valorizar suas conquistas e sempre ter seus pés no chão. Vc é bom no que faz eles apostaram bem♥️
#
# Tweet 30: @DonElece parabéns!!! todo sucesso pra você!!! 👏
#
# Tweet 31: @DonElece Se seus pais estiverem vivos, fala pra eles, não pro Twitter. E parabéns!
#
# Tweet 32: @endrewdsilv4 @DonElece E as vezes ainda KKKK
#
# Tweet 33: @DonElece Parabéns rapaz.
#
# Tweet 34: @DonElece Vc trampa como autônomo na área de Design?
#
# Tweet 35: @Otenn013 @DonElece Que porra de frase é essa kkkkkkkkkkk
#
# Tweet 36: @DonElece Parabéns 👏👏👏
#
# Tweet 37: @DonElece oxe e eu chorei foi
#
# Tweet 38: @DonElece Tu me conquistou o respeito nessa frase aqui: “mudou a NOSSA vida" …
#
# Tweet 39: @DonElece O reconhecimento e a gratidão te levarão muito
# mais longe ainda meu querido. Deus te abençoe! Fiquei emocionado e feliz lendo seu post
#
# Tweet 40: @DonElece Rapaz parabéns! Vc não vai se arrepender. Esse ano tbm peguei meu primeiro macbook e nossa é um sonho realizado🥹

# %%
#@title Instalando a biblioteca de integração com o LangChain
# !pip install -qU langchain-google-genai

# %%
#@title Definindo a chave da API

import getpass
import os

os.environ["GOOGLE_API_KEY"] = userdata.get('keyGemini')

GOOGLE_API_KEY = userdata.get('keyGemini')

# %%
#@title Instanciando o modelo Gemini

from langchain_google_genai import ChatGoogleGenerativeAI

modelo = ChatGoogleGenerativeAI(model="gemini-2.5-flash", google_api_key = GOOGLE_API_KEY, temperature=0)

# %%
#@title Definindo o template do prompt para análise de sentimento

from langchain_core.prompts import PromptTemplate

template = (
    'Avalie o sentimento do seguinte tweet. '
    'Classifique como "positivo", "negativo", "neutro" ou "indefinido". '
    'Retorne na seguinte forma: categoria; sentimento. '
    'Classifique como "felicidade", "alegria", "esperança", "interesse", "inspiração", "diversão", "admiração", "confiança", "otimismo", "satisfação", "respeito", '
    '"tristeza", "raiva", "ironia", "angústia", "culpa, "vergonha", "desespero", "desconfiança", "pânico", "mágoa", "repulsa", "pessimismo", "pertubação", '
    '"dúvida", "nojo", "medo", "surpresa", "desprezo", "desejo", "decepção", "tédio" ou "indefinido". '
    'Exemplo: positivo; felicidade, tristeza, raiva, ironia, angústia. '
    'Não retorne texto adicional. Tweet: {tweet}'
)

prompt = PromptTemplate.from_template(template)

# %%
#@title Função para o LLM processar a lista de tweets
def processando_tweets(lista_tweets, lista_resultados):
  for tweet_text in lista_tweets:
      resposta_obj = modelo.invoke(prompt.format(tweet=tweet_text))
      resposta = resposta_obj.content  # Use .content para obter a string resposta
      partes = resposta.split(';')
      if len(partes) == 2:
          categoria = partes[0].strip().lower()
          sentimentos = [x.strip().lower() for x in partes[1].split(",")]
      else:
          categoria = "indefinido"
          sentimentos = []
      lista_resultados.append({
          "tweet": tweet_text,
          "categoria": categoria,
          "sentimentos": sentimentos
      })

# %%
#@title Processando cada resposta do primeiro tweet (Elon Musk)

resultados_sentimentos_1 = []
processando_tweets(all_texts_1, resultados_sentimentos_1)

# %%
print(resultados_sentimentos_1)
# Out:
# [{'tweet': '@PookiesParadise @GoldBoy542524 @elonmusk Idk pretty sure right wingers was pushin for death on liberal ppl too at some point bc of their views, what changed https://t.co/HPHNbOXeux', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'ironia', 'dúvida']}, {'tweet': '@elonmusk Whoever the shooter may be, the only good thing they managed to do was save us from a president Kirk in 2040.', 'categoria': 'negativo', 'sentimentos': ['desprezo', 'ironia', 'raiva']}, {'tweet': '@elonmusk What is the TRUTH about his death?', 'categoria': 'negativo', 'sentimentos': ['dúvida']}, {'tweet': "@FoundersEcho @mandala_mandy @elonmusk You have a problem with God's will? \n\nSatanist", 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'ironia']}, {'tweet': '@elonmusk @Davidharris_9 😭', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'angústia']}, {'tweet': '@elonmusk @fatherdoge4207 He died instantly assclown!', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@Shadow_Vx88 @PookiesParadise @elonmusk Low IQ opinion.\n\nNow turn to the left', 'categoria': 'negativo', 'sentimentos': ['desprezo']}, {'tweet': '@elonmusk It was not comparable with life. Too much damage.😢 so full of life and promise. Amazing young man. Gone in an instant. Irreplaceable 🤦🏼\u200d♀️ 💔', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'mágoa', 'angústia', 'desespero', 'perturbação', 'decepção']}, {'tweet': "@JimEagleUC @PookiesParadise @elonmusk if ur logic is correct, everyone and I mean everyone would die, there will never be one thing that every human being can agree upon. Not to mention, that every person has a different idea of what's right and what's wrong, End topic.", 'categoria': 'negativo', 'sentimentos': ['raiva', 'pessimismo', 'perturbação', 'desprezo']}, {'tweet': '@elonmusk @saxsonmusk5 😭😭😭🙏🏻✨', 'categoria': 'negativo', 'sentimentos': ['angústia']}, {'tweet': '@elonmusk Much more better', 'categoria': 'neutro', 'sentimentos': ['indefinido']}, {'tweet': '@elonmusk @youngchris_0852 Sorry !', 'categoria': 'negativo', 'sentimentos': ['culpa']}, {'tweet': "@JacksonDann @elonmusk Well think about context first before you consider whether or not it's true perhaps", 'categoria': 'neutro', 'sentimentos': ['indefinido']}, {'tweet': '@elonmusk @saxsonmusk5 🥺we will forever be changed by his goodness. May his name always be remembered for the love of God and Jesus he proudly proclaimed ❤️', 'categoria': 'positivo', 'sentimentos': ['admiração', 'respeito', 'inspiração', 'esperança', 'otimismo', 'tristeza']}, {'tweet': '@dallaswright71 @Emilia__writes @elonmusk Well he also wasn’t a democrat😭', 'categoria': 'negativo', 'sentimentos': ['ironia', 'desprezo']}, {'tweet': '@Deveqv_2 @jessejacobsof @rax13gaming @naifvsexpert @elonmusk They are doing that thing again where they pretend the parties didn’t switch.', 'categoria': 'negativo', 'sentimentos': ['ironia', 'desprezo']}, {'tweet': '@rax13gaming @naifvsexpert @elonmusk Love how y’all pretend the parties didn’t switch. Most of the political violence in your country comes from the far right. Stop pretending you’re still the party of Lincoln 💀', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@elonmusk @elonspacexms A 30-06 would shatter a 1000lb cow leg, with stronger bones. I shot my dad’s once &amp; it put me a foot back on the ground. Now truthfully it souls Oswald-ish to me. (That would be back in the 60’s)', 'categoria': 'negativo', 'sentimentos': ['perturbação']}, {'tweet': '@TrumpUpdateHQ @elonmusk If someone could turn back time,how many misfortunes could be fixed !😥\n\nA piece of advice:\n👉Prevention is the mother of wisdom,and one step before fatality!\n👉Fatality has no remorse,pauses or empathy,it always looks for opportunities.\n\nGod bless you🙏❤️ \n\nRIP Charlie Kirk🙏🌹', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'angústia', 'desejo', 'decepção', 'medo', 'pessimismo', 'mágoa', 'respeito', 'esperança']}, {' ...

# %%
#@title Processando cada resposta do segundo tweet (Tiago Santineli)

resultados_sentimentos_2 = []
processando_tweets(all_texts_2, resultados_sentimentos_2)

# %%
print(resultados_sentimentos_2)
# Out:
# [{'tweet': '@graziela_galli @SaxGuga @tiagosantineli @SecRubio @SecState @DeputySecState Não tem nada pra fazer não militante estrangeira? Vai ler pra cego ou fazer uma doação pra caridade', 'categoria': 'negativo', 'sentimentos': ['raiva', 'ironia', 'desprezo', 'perturbação']}, {'tweet': '@carluxo1921 @tiagosantineli Tem a puta Gil tbm KKKKKKKKKKK', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'diversão']}, {'tweet': '@tiagosantineli sua vida é tão triste assim mano?', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'desprezo']}, {'tweet': '@ZA_WWARUDO @tiagosantineli O mesmo que disse que se a filha de dez anos fosse estuprada, ele forçaria ela a manter o bebê e faria ela passar pelo parto? Talvez tenha sido um livramento! \U0001fae9', 'categoria': 'positivo', 'sentimentos': ['satisfação', 'raiva', 'desprezo', 'ironia']}, {'tweet': '@Leaah_lin_ @tiagosantineli começou oque', 'categoria': 'neutro', 'sentimentos': ['dúvida']}, {'tweet': '@graziela_galli @tiagosantineli @SecRubio @DeputySecState Hi, @SecRubio and @DeputySecState! I\'m from Brazil. Keep your 3 Pages constitution, all that "WE THE PEOPLE..." crap and put up your a$$.\n\n@graziela_galli, você tem algum problema com a minha liberdade de expressão? Vai dizer que eu ultrapassei o limite do humor? Hahahahaha...', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'ironia', 'repulsa']}, {'tweet': '@sdsyv1 @ZA_WWARUDO @tiagosantineli c é bem machão na internet né', 'categoria': 'negativo', 'sentimentos': ['ironia', 'desprezo']}, {'tweet': '@ZA_WWARUDO @tiagosantineli Começou já kkkk', 'categoria': 'neutro', 'sentimentos': ['diversão']}, {'tweet': '@Matheusol230407 @tiagosantineli Se for chorar manda áudio, seu cuzão chorão!', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@tiagosantineli Cabeça de ozempic', 'categoria': 'negativo', 'sentimentos': ['desprezo', 'ironia']}, {'tweet': '@saindodenarnia1 @ZA_WWARUDO @tiagosantineli O assassino fascista ainda tá vivo', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@tiagosantineli ai scrrrr', 'categoria': 'positivo', 'sentimentos': ['diversão', 'surpresa', 'ironia']}, {'tweet': '@DoIIIisa @tiagosantineli Do que eu vi do Nikolas, ele simplesmente apontou q esse pessoal n ia ter misericórdia de qm n fosse do msm lado q eles e por isso deviam ser reconhecidos como inimigos, n vi nada sobre ter empatia', 'categoria': 'negativo', 'sentimentos': ['desconfiança', 'perturbação', 'dúvida']}, {'tweet': '@EveMs0 @DoIIIisa @tiagosantineli https://t.co/obqDvZxSuz', 'categoria': 'indefinido', 'sentimentos': ['indefinido']}, {'tweet': '@EveMs0 @DoIIIisa @tiagosantineli Aqui https://t.co/jAGdKygdIc', 'categoria': 'neutro', 'sentimentos': ['indefinido']}, {'tweet': '@EveMs0 @DoIIIisa @tiagosantineli Saiu no jornal, vê lá deixa e procurar e linkar aqui pera ai', 'categoria': 'neutro', 'sentimentos': ['interesse']}, {'tweet': '@graziela_galli @tiagosantineli @SecRubio @SecState @DeputySecState https://t.co/zTgjf6Zqv7', 'categoria': 'indefinido', 'sentimentos': ['indefinido']}, {'tweet': '@Convertor717 @deekvlt @tiagosantineli https://t.co/UQUlOF6end', 'categoria': 'indefinido', 'sentimentos': ['indefinido']}, {'tweet': '@sandrazarp @tiagosantineli Veia vai aquietar o fogo do teu cu', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@rakelzinha_dias @mascatora @tiagosantineli 35 anos tá chegando hein, melhor preparar a cordinha ó molestado pelo tio', 'categoria': 'negativo', 'sentimentos': ['ironia', 'perturbação', 'desprezo']}, {'tweet': '@Kaiser11131 @tiagosantineli Calma aí ó cpzeiro', 'categoria': 'neutro', 'sentimentos': ['indefinido']}, {'tweet': '@pedrobeldum @MaranaoSilva @tiagosantineli Você foi estuprado pelo tio, com certeza', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@ZA_WWARUDO @tiagosantineli Só recebeu o que pregava pra família dos outros. Besta é quem ainda se compadece.', 'categoria': ...

# %%
#@title Processando cada resposta do terceiro tweet (Ian Neves)

resultados_sentimentos_3 = []
processando_tweets(all_texts_3, resultados_sentimentos_3)

# %%
print(resultados_sentimentos_3)
# Out:
# [{'tweet': '@leoodoritos @ianfneves ELE defendeu que execuções de pena de morte fossem públicas, televisionadas e até patrocinadas pela Coca-Cola, e que crianças deveriam assistir\n\nEU particularmente acho paia pra krl alguém morrer assim\n\né ELE quem acha ok, quem sou eu e quem é vc pra achar errado', 'categoria': 'negativo', 'sentimentos': ['repulsa', 'nojo', 'pertubação', 'desprezo', 'ironia', 'raiva', 'angústia']}, {'tweet': '@Rafha7x @ianfneves kkkkkkkk O Xingador.', 'categoria': 'positivo', 'sentimentos': ['diversão', 'ironia']}, {'tweet': '@leoodoritos @ianfneves O beta entrou em parafuso pra defender o charlie pescocinho https://t.co/wtlfNVRXAQ', 'categoria': 'negativo', 'sentimentos': ['desprezo', 'ironia']}, {'tweet': '@PalmeirasFort @leoodoritos @ianfneves O Brasil segue sendo líder em assassinatos e aqui a arma é liberada?', 'categoria': 'negativo', 'sentimentos': ['raiva', 'angústia', 'desespero']}, {'tweet': '@GoblinWasabi @ianfneves como?fiquei curioso, o seu caráter varia de acordo com o suposto caráter de outro?', 'categoria': 'neutro', 'sentimentos': ['curiosidade', 'dúvida']}, {'tweet': '@GabZozimo @ianfneves além do mais, você não falou nada sobre sentir pena dele, você não sente pena de um inocente ser assassinado?não sente pena da esposa e da filha? não quero te desmoralizar, é só uma duvida, porque eu acredito que todos nós, desde adão ate o último a nascer, somos podres iguais.', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'raiva', 'dúvida']}, {'tweet': '@GabZozimo @ianfneves nao usei ad hominem, pelo contrário, te achei inteligente, vi teu perfil. so queria que vc me explicasse o termo que usou e como ele se enquadra em kirk. um mesmo termo pode ter significados diferentes pra duas pessoas não acha?', 'categoria': 'neutro', 'sentimentos': ['interesse', 'dúvida']}, {'tweet': '@xfrangobacon @ianfneves sabe o porquê de eu não entrar no merito moral?pq todos nos somos a mesma merda que ele, nunca teve um misero ser humano bom na terra, o unico que era um pouco mais que humano, a gente conseguiu a proeza de crucificar ele, e assim foi feito, pra gente não ter o que merece:inferno', 'categoria': 'negativo', 'sentimentos': ['pessimismo', 'desespero', 'culpa', 'ironia', 'desprezo', 'tristeza', 'angústia']}, {'tweet': '@xfrangobacon @ianfneves sabe, a gente precisa dialogar mais com as diferenças, não espalhar o ódio, meu pano não tá sujo, sinto pena dele ter morrido, assim como sentiria de qualquer pessoa na face da terra, sou de direita e contra pena de morte, curioso né?como se sente ao ficar feliz com morte alheia?', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'raiva', 'desconfiança', 'repulsa', 'desprezo']}, {'tweet': '@xfrangobacon @ianfneves betinha?é o melhor que consegue sr sigma? não queria entrar no merito moral da vida dele, porque julgar esse tipo de coisa nao cabe à mim. eu nao te pedi pra provar nada, somente pra explicar um termo que vc citou, e que apontou que quem detem tal característica não é gente.', 'categoria': 'negativo', 'sentimentos': ['ironia', 'desprezo', 'raiva', 'desconfiança']}, {'tweet': '@RedBolasha @ianfneves claro que empatia existe kkkkk ele sempre existiu, a critica dele era em relação à termologia. mas me diga, você se limita a sentir empatia apenas por quem você gosta? eu sentiria empatia ate se o lula ou bolsonaro morressem, quem dirá um incente', 'categoria': 'positivo', 'sentimentos': ['confiança', 'interesse', 'ironia', 'diversão', 'respeito']}, {'tweet': '@leoodoritos @ianfneves Não preciso te provar nada, e usar ad hominem é só uma prova que você não tem o que falar.', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@leoodoritos @ianfneves Se vc não se deu ao trabalho de ver algum mísero video das falas dele, e ta vindo aqui falar bosta, eu não tenho que provar nada. TA CHEIO de video desse MERDA despejando preconceito e falas segregacionistas. Seu pano ta sujo, vai lavar ele, betinha.', 'categoria': 'negativo', 'sentime ...

# %%
#@title Processando cada resposta do quarto tweet (Don Elece)

resultados_sentimentos_4 = []
processando_tweets(all_texts_4, resultados_sentimentos_4)

# %%
print(resultados_sentimentos_4)
# Out:
# [{'tweet': '@DonElece vc tem 26 anos? :0', 'categoria': 'neutro', 'sentimentos': ['dúvida']}, {'tweet': '@DonElece @PenseNBA Deve ser insuportável para eles escutar isso todo dia kkkkkkk pqp', 'categoria': 'positivo', 'sentimentos': ['diversão', 'ironia', 'satisfação']}, {'tweet': '@PenseNBA santa burrice', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo']}, {'tweet': '@DonElece Faz 3 anos que trabalho por conta. Também como designer.\n\nGanhando meu dinheirinho sem precisar sair do meu quarto.\n\nMinha meta era ganhar 5 mil. Ganhei mês passado.\n\nQuase chorei.', 'categoria': 'positivo', 'sentimentos': ['satisfação', 'alegria', 'otimismo']}, {'tweet': '@DonElece Excelente trabalho o de seus pais e o seu. Parabéns pela bela família e sucesso sempre na sua vida através da receita que te trouxe até aqui: trabalho honesto e dando nó em pingo d’água quando necessário.', 'categoria': 'positivo', 'sentimentos': ['admiração', 'respeito', 'otimismo']}, {'tweet': '@DonElece Eu tmb sou designer, mas nunca consegui um cliente, comecei em 2023 nessa área, vou deixar aqui as minhas artes de futebol e uma que eu fiz para a coca cola por diversão e para aperfeiçoar as minhas técnicas https://t.co/WpVIxOXUqn', 'categoria': 'positivo', 'sentimentos': ['interesse', 'inspiração', 'diversão', 'satisfação', 'esperança', 'otimismo', 'decepção']}, {'tweet': '@DonElece don, queria muito entrar nessa área, mas tenho conhecimento extremamente básico (pra não dizer 0), tem alguma recomendação de curso/professor/lugar em que eu possa aprender, claro, pra quem quer mesmo consegue se virar e achar, mas eu queria uma dica de alguém experiente na área', 'categoria': 'positivo', 'sentimentos': ['desejo', 'interesse', 'esperança', 'confiança', 'otimismo', 'respeito']}, {'tweet': '@DonElece parabéns pela conquista!', 'categoria': 'positivo', 'sentimentos': ['admiração', 'satisfação']}, {'tweet': '@DonElece Que história legal!', 'categoria': 'positivo', 'sentimentos': ['admiração', 'interesse']}, {'tweet': '@DonElece E doido isso, inverso a isso, tenho um amigo meu que é animal para desenvolver material e super inteligente nas ideias, so que e doido. Gosta de beber e viver a vida, quer nada com nada, mó pecado, mas otimo profissional nada a ver com o assunto, so lembrei das oportunidades...', 'categoria': 'neutro', 'sentimentos': ['admiração', 'tristeza', 'surpresa']}, {'tweet': '@DonElece ♥️♥️♥️', 'categoria': 'positivo', 'sentimentos': ['felicidade', 'alegria', 'admiração']}, {'tweet': '@DonElece 🥰🥰🥰🥰', 'categoria': 'positivo', 'sentimentos': ['felicidade', 'alegria', 'admiração']}, {'tweet': '@DonElece Quero doar um MacBook 2021 com tela quebrada mas q funciona com um monitor externo. Quem tiver interesse me avisa', 'categoria': 'neutro', 'sentimentos': ['interesse']}, {'tweet': '@defcondoug @DonElece Pra um ri o outro tem que chorar paizão', 'categoria': 'negativo', 'sentimentos': ['tristeza', 'mágoa', 'angústia', 'pessimismo', 'decepção']}, {'tweet': '@DonElece Pra quem trabalha no design gráfico ali fazendo arte no Canva, qual é o Mac indicado, mais custo beneficio', 'categoria': 'neutro', 'sentimentos': ['interesse', 'dúvida']}, {'tweet': '@DonElece Parabéns pelo desenvolvimento e desempenho, o trabalho devolve irmão.', 'categoria': 'positivo', 'sentimentos': ['admiração', 'respeito', 'confiança', 'otimismo', 'alegria', 'satisfação']}, {'tweet': '@DonElece To com acer q só falta me implorar pra não ligar ele kkk não vejo a hora de ter um Mac 🙏', 'categoria': 'negativo', 'sentimentos': ['frustração', 'desejo']}, {'tweet': '@DonElece Com certeza eles têm muito orgulho! Mais uma vez, parabéns!', 'categoria': 'positivo', 'sentimentos': ['orgulho', 'admiração', 'satisfação']}, {'tweet': '@DonElece Parabens mano!!', 'categoria': 'positivo', 'sentimentos': ['alegria']}, {'tweet': '@DonElece também comecei com um notebook bem fraco 1gb de ram, intel celeron, lenovo.\n\nera o que tinha e deu certo!', 'categoria': 'positivo', 'sentimentos': ['satisfação ...

# %% [markdown]
# # Análise dos resultados obtidos
# Vamos utilizar gráficos com os resultados obtidos para visualizar a distribuição dos sentimentos identificados pela ferramenta.

# %%
import matplotlib.pyplot as plt
from collections import Counter

def desenhar_grafico_1(contagem_categorias):
  plt.figure(figsize=(8, 5))
  plt.bar(contagem_categorias.keys(), contagem_categorias.values(), color='skyblue')
  plt.title("Quantidade de Tweets por Categoria")
  plt.xlabel("Categoria")
  plt.ylabel("Quantidade")
  plt.grid(axis='y', linestyle='--', alpha=0.7)
  plt.show()

# %%
contagem_categorias_1 = Counter(item["categoria"] for item in resultados_sentimentos_1)
desenhar_grafico_1(contagem_categorias_1)

# %%
contagem_categorias_2 = Counter(item["categoria"] for item in resultados_sentimentos_2)
desenhar_grafico_1(contagem_categorias_2)

# %%
contagem_categorias_3 = Counter(item["categoria"] for item in resultados_sentimentos_3)
desenhar_grafico_1(contagem_categorias_3)

# %%
contagem_categorias_4 = Counter(item["categoria"] for item in resultados_sentimentos_4)
desenhar_grafico_1(contagem_categorias_4)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from itertools import chain

def desenhar_grafico_2(resultados_sentimentos):
  # Substituir sentimento vazio por "indefinido"
  listas_de_sentimentos = [
      item["sentimentos"] if item["sentimentos"] else ["indefinido"]
      for item in resultados_sentimentos
  ]

  todos_sentimentos = list(chain.from_iterable(listas_de_sentimentos))

  contagem_sentimentos = Counter(todos_sentimentos)
  mais_comuns = contagem_sentimentos.most_common(10)

  # Remove "indefinido" do gráfico
  mais_comuns = [item for item in mais_comuns if item[0] != "indefinido"]

  if mais_comuns:
      labels, counts = zip(*mais_comuns)
      plt.figure(figsize=(10, 6))
      sns.barplot(x=counts, y=labels, palette="viridis")
      plt.title("Top 10 Sentimentos Mais Frequentes")
      plt.xlabel("Número de Tweets")
      plt.ylabel("Sentimento")
      plt.show()
  else:
      print("Não há sentimentos válidos para plotar.")

# %%
desenhar_grafico_2(resultados_sentimentos_1)
# Out:
# /tmp/ipython-input-2395048721.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=labels, palette="viridis")

# %%
desenhar_grafico_2(resultados_sentimentos_2)
# Out:
# /tmp/ipython-input-2395048721.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=labels, palette="viridis")

# %%
desenhar_grafico_2(resultados_sentimentos_3)
# Out:
# /tmp/ipython-input-2395048721.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=labels, palette="viridis")

# %%
desenhar_grafico_2(resultados_sentimentos_4)
# Out:
# /tmp/ipython-input-2395048721.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=labels, palette="viridis")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def nuvem_palavras(resultados_sentimentos):
  text = ' '.join([' '.join(s) for s in [item["sentimentos"] for item in resultados_sentimentos if item["sentimentos"]]])
  wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

  plt.figure(figsize=(10,5))
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.axis('off')
  plt.title('Nuvem de Palavras dos Sentimentos')
  plt.show()

# %%
nuvem_palavras(resultados_sentimentos_1)

# %%
nuvem_palavras(resultados_sentimentos_2)

# %%
nuvem_palavras(resultados_sentimentos_3)

# %%
nuvem_palavras(resultados_sentimentos_4)

# %%
import pandas as pd
import seaborn as sns

def desenhar_grafico_3(resultados_sentimentos):
  # Montar dataframe para plot
  df = pd.DataFrame([
      {"categoria": item["categoria"], "sentimento": s}
      for item in resultados_sentimentos for s in item["sentimentos"]
  ])

  plt.figure(figsize=(12,6))
  sns.countplot(data=df, x='categoria', hue='sentimento')
  plt.xticks(rotation=0)
  plt.title("Distribuição dos Sentimentos por Categoria")
  plt.show()

# %%
desenhar_grafico_3(resultados_sentimentos_1)

# %%
desenhar_grafico_3(resultados_sentimentos_2)

# %%
desenhar_grafico_3(resultados_sentimentos_3)

# %%
desenhar_grafico_3(resultados_sentimentos_4)

# %% [markdown]
# # Conclusão
#
# Na grande **maioria** dos tweets envolvidas em ambos os espectros políticos, tivemos uma predominância alta de **sentimentos negativos**, o que após a interpretação de contexto e resultados, pode ocorrer devido a dois fatores:
#
#
#
# 1.   O contexto envolto dos tweets é um assunto "pesado", envolve morte e extremismo, então em muitos deles, independente do tom do autor do texto, a ferramenta vai detectar o assunto e encaixar na categoria "negativo" por conta disso.
# 2.   Ambos os tweets tem um alto número de visualizações e "furaram suas bolhas" de debate, alcançando um público que não necessariamente faz parte do mesmo espectro político do autor do tweet, o que resulta em muitas comentários como ataques diretos ao autor ou se usando de ironia em seu comentário, fazendo com que seja enquadrado na categoria "negativa".

# %% [markdown]
# # Expandindo a análise para detectar o grau de negatividade da rede social X
# Como o resultado da análise nos surpreendeu com um **alto nível de negatividade**, resolvemos expandir para um contexto mais amplo, buscando obter uma resposta para a nossa teoria referente ao possível alto grau de negatividade na rede social X no Brasil como um todo!
#
# Para isso, utilizaremos as mesmas estratégias, funções e ferramentas de análise, mas com um corpus diferente. Queremos que ele represente um alto grau do tipo de conteúdo aos quais os usuários estão expostos na rede, portanto, buscamos o conteúdo produzido pelas contas mais influentes do Brasil.

# %% [markdown]
# ![influentes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Capturando as contas mais populares do Brasil
#
# Queremos extrair as contas mais populares no Brasil para fazer nossa análise.
#
# Para isso, pegaremos o conteúdo de uma página que faz essa análise de quais são as contas mais populares do Brasil, e usaremos o Gemini para gerar a provável @username da conta descrita no texto, para que possamos extrair as informações da conta com a API do Twitter.
#
# Os passos consistem no seguinte:
# - Extrair o conteúdo em texto do site: "https://www.favikon.com/blog/top-x-influencers-brazil"
# - Usar Gemini para gerar os supostos @userName dos ussuários descritos no texto
# - Usar os @userName obtidos para buscar os seus Tweets mais recentes na API

# %%
#@title Prompt usado no Gemini para capturar os nomes dos usuários a partir do conteúdo da página

from google.colab import userdata
from langchain_core.prompts import PromptTemplate

# Prompt para extrair nome + handle_x
template = (
    "Você é um assistente que extrai dados em JSON.\n"
    "A partir do TEXTO abaixo, extraia UMA LISTA JSON, sem texto antes ou depois.\n"
    "Cada item da lista deve ser um objeto com a chave EXATA: "
    '"nome".\n'
    "TEXTO:\n{conteudo_pagina}\n\n"
    "Responda SOMENTE com a lista JSON."
)

prompt = PromptTemplate.from_template(template)

# %%
#@title Função para utilizar o prompt do Gemini no conteúdo da página fornecido, retornando os nomes dos usuários presentes nele

def extrair_contas_favikon(conteudo_pagina: str):
    mensagem = prompt.format(conteudo_pagina=conteudo_pagina)
    resposta = modelo.invoke(mensagem)
    texto = resposta.content if hasattr(resposta, "content") else resposta.text

    texto_limpo = texto.strip()
    texto_limpo = texto_limpo.removeprefix("```json").removeprefix("```")
    texto_limpo = texto_limpo.removesuffix("```")
    print(texto_limpo)

    try:
        dados = json.loads(texto_limpo)
    except json.JSONDecodeError:
        print("Falha ao fazer parse do JSON. Conteúdo bruto da resposta:")
        print(texto)
        return []

    if not isinstance(dados, list):
        print("Formato inesperado. Esperado: lista de objetos JSON.")
        print(dados)
        return []

    return dados

# %%
#@title Converte o conteúdo da página HTML em string

import requests
from bs4 import BeautifulSoup

url = "https://www.favikon.com/blog/top-x-influencers-brazil"
resp = requests.get(url)
resp.raise_for_status()
html_str = resp.text

soup = BeautifulSoup(html_str, "html.parser")
texto_str = soup.get_text(separator="\n", strip=True)

print("Trecho do texto da página:")
print(texto_str[:1000])
# Out:
# Trecho do texto da página:
# Top 20 X (Twitter) Influencers in Brazil in 2025 - Favikon
# For brands
# For brands
# For creators
# Products
# Find
# Make the right moves to spot the best creators for your brand
# AI Search
# Rankings
# Radar
# Lookalikes
# Engage
# Run campaigns, manage creators, and track results that tie back to you
# Campaigns
# Inbox
# Contacts
# Insights
# Get the insights you need on any creator or brand, anytime, anywhere
# Profile
# Extension
# Pricing
# Resources
# Blog & Articles
# Your ultimate ressource for the creator economy
# Methodology & Rankings
# About Favikon, rankings, tools & much more.
# Blog & Articles
# Favikon V3 | The Future of Influencer Marketing Out Now
# Favikon V3 is out now. Check what's new ->
# 10 LinkedIn Influencer Marketing Tips From Top Marketers
# Many B2B marketers are unsure how to approach LinkedIn influencer marketing, from pricing posts to measuring ROI. This case study analyzes top campaigns and highlights 10 expert tips to help brands succeed with creators on LinkedIn.
# The B2B LinkedIn Strategy Driving 50% of

# %%
#@title Chamar o Gemini para extrair os nomes das contas citadas nos textos
contas = extrair_contas_favikon(texto_str)

nomes = [c.get("nome") for c in contas if c.get("nome")]
print(nomes)
# Out:
# [
#   {
#     "nome": "Felipe Neto"
#   },
#   {
#     "nome": "Danilo Gentili"
#   },
#   {
#     "nome": "Vinicios Betiol"
#   },
#   {
#     "nome": "Maisa Silva"
#   },
#   {
#     "nome": "Lorena Orsi"
#   },
#   {
#     "nome": "Guilherme Gama"
#   },
#   {
#     "nome": "Erika Hilton"
#   },
#   {
#     "nome": "Eduardo Bolsonaro"
#   },
#   {
#     "nome": "Tiago Santineli"
#   },
#   {
#     "nome": "Whindersson Nunes"
#   },
#   {
#     "nome": "Alvaro"
#   },
#   {
#     "nome": "Leonardo Lucas"
#   },
#   {
#     "nome": "Vinicius Jr."
#   },
#   {
#     "nome": "Lucas"
#   },
#   {
#     "nome": "Rafael Lange"
#   },
#   {
#     "nome": "Rodrygo Goes"
#   },
#   {
#     "nome": "Anitta"
#   },
#   {
#     "nome": "Luiz Inácio Lula da Silva"
#   },
#   {
#     "nome": "Nikolas Ferreira"
#   },
#   {
#     "nome": "Neymar Jr"
#   }
# ]
#
# ['Felipe Neto', 'Danilo Gentili', 'Vinicios Betiol', 'Maisa Silva', 'Lorena Orsi', 'Guilherme Gama', 'Erika Hilton', 'Eduardo Bolsonaro', 'Tiago Santineli', 'Whindersson Nunes', 'Alvaro', 'Leonardo Lucas', 'Vinicius Jr.', 'Lucas', 'Rafael Lange', 'Rodrygo Goes', 'Anitta', 'Luiz Inácio Lula da Silva', 'Nikolas Ferreira', 'Neymar Jr']

# %%
#@title A partir da lista de nomes, usar um prompt Gemini para descobrir o @userName

prompt_usernames = PromptTemplate.from_template(
    "Você é um assistente que descobre arrobas de famosos no X (Twitter).\n"
    "Dado a lista de nomes abaixo, devolva SOMENTE um array JSON, sem texto extra.\n"
    "Cada item deve ter as chaves exatas: \"nome\" e \"username_x\".\n"
    "Use o @ exato que a pessoa usa no X, sem URL e sem @ (por exemplo: \"neymarjr\").\n"
    "Se não souber, use null em \"username_x\".\n\n"
    "NOMES:\n{lista_nomes}"
)

def sugerir_usernames_com_gemini(nomes):
    lista_nomes_str = "\n".join(nomes)
    mensagem = prompt_usernames.format(lista_nomes=lista_nomes_str)
    resp = modelo.invoke(mensagem)
    texto = resp.content if hasattr(resp, "content") else resp.text

    # se o modelo devolver com ```
    texto_limpo = texto.strip()
    texto_limpo = texto_limpo.removeprefix("```json").removeprefix("```")
    texto_limpo = texto_limpo.removesuffix("```").strip()

    try:
        dados = json.loads(texto_limpo)
    except json.JSONDecodeError:
        print("Falha ao fazer parse do JSON. Resposta bruta:")
        print(texto)
        return []

    if not isinstance(dados, list):
        print("Formato inesperado. Esperado lista JSON.")
        print(dados)
        return []

    return dados

# %%
contas_sugeridas = sugerir_usernames_com_gemini(nomes)

print("Sugeridos pelo Gemini:")
for c in contas_sugeridas:
    print(c.get("nome"), "-", c.get("username_x"))
# Out:
# Sugeridos pelo Gemini:
# Felipe Neto - felipeneto
# Danilo Gentili - DaniloGentili
# Vinicios Betiol - viniciosbetiol
# Maisa Silva - maisa
# Lorena Orsi - None
# Guilherme Gama - None
# Erika Hilton - ErikakHilton
# Eduardo Bolsonaro - BolsonaroSP
# Tiago Santineli - tiagosantineli
# Whindersson Nunes - whindersson
# Alvaro - None
# Leonardo Lucas - None
# Vinicius Jr. - vinijr
# Lucas - None
# Rafael Lange - cellbit
# Rodrygo Goes - RodrygoGoes
# Anitta - anitta
# Luiz Inácio Lula da Silva - LulaOficial
# Nikolas Ferreira - nikolas_dm
# Neymar Jr - neymarjr

# %%
import time
import requests

BASE_URL_INFO = "https://api.twitterapi.io/twitter/user/info"

def get_user_by_username(username: str, tentativas: int = 3, espera_inicial: float = 2.0):
    username = username.lstrip("@").strip()
    espera = espera_inicial

    for tentativa in range(1, tentativas + 1):
        params = {"userName": username}
        resp = requests.get(BASE_URL_INFO, headers=headers, params=params)

        # Sucesso
        if resp.status_code == 200:
            data = resp.json()
            user = data.get("data")
            if not user:
                print(f"Nenhum usuário retornado para '{username}'.")
                return None
            return user

        # Too Many Requests (free-tier: 1 req a cada 5s)
        if resp.status_code == 429:
            print(
                f"Erro 429 (Too Many Requests) ao buscar '{username}' "
                f"(tentativa {tentativa}/{tentativas}): {resp.text}"
            )
            # espera fixa de 5s, conforme mensagem da API
            if tentativa < tentativas:
                time.sleep(5)
                continue
            return None

        # Erro interno do servidor
        if resp.status_code == 500:
            print(
                f"Erro 500 ao buscar '{username}' (tentativa {tentativa}/{tentativas}): "
                f"{resp.text}"
            )
            if tentativa < tentativas:
                time.sleep(espera)
                espera *= 2
                continue
            return None

        # Outros erros (400, 401, 403, etc.) sem retry
        print(f"Erro {resp.status_code} ao buscar '{username}': {resp.text}")
        return None

    return None

# %%
import time

def obter_ids_a_partir_de_sugestoes(contas_sugeridas):
    """
    contas_sugeridas: lista de dicts {nome, username_x} vinda do Gemini
    Respeita o limite free-tier: 1 request a cada 5 segundos.
    """
    resultados = []
    for conta in contas_sugeridas:
        nome = conta.get("nome")
        username_x = conta.get("username_x")

        if not username_x:
            resultados.append({
                "nome": nome,
                "username_x": None,
                "id": None,
                "validado": False,
            })
            continue

        # Pausa de 5 segundos entre requisições para evitar 429
        time.sleep(5)

        user = get_user_by_username(username_x)
        if user is None:
            resultados.append({
                "nome": nome,
                "username_x": username_x,
                "id": None,
                "validado": False,
            })
            continue

        resultados.append({
            "nome": nome,
            "username_x": user.get("userName", username_x.lstrip("@")),
            "id": user.get("id"),
            "validado": True,
            "name_api": user.get("name"),
        })

    return resultados

# %%
contas_com_id = obter_ids_a_partir_de_sugestoes(contas_sugeridas)

print("\nResultado final (nome / @ / id / validado):")
for c in contas_com_id:
    print(c["nome"], "-", c["username_x"], "-", c["id"], "-", c["validado"])
# Out:
# Resultado final (nome / @ / id / validado):
# Felipe Neto - felipeneto - 14128609 - True
# Danilo Gentili - DaniloGentili - 14213711 - True
# Vinicios Betiol - ViniciosBetiol - 115678425 - True
# Maisa Silva - maisa - 2203709322 - True
# Lorena Orsi - None - None - False
# Guilherme Gama - None - None - False
# Erika Hilton - ErikakHilton - 738143559920934912 - True
# Eduardo Bolsonaro - BolsonaroSP - 74756085 - True
# Tiago Santineli - tiagosantineli - 215282625 - True
# Whindersson Nunes - whindersson - 230186518 - True
# Alvaro - None - None - False
# Leonardo Lucas - None - None - False
# Vinicius Jr. - vinijr - 2329070186 - True
# Lucas - None - None - False
# Rafael Lange - cellbit - 451200058 - True
# Rodrygo Goes - RodrygoGoes - 815671379202887684 - True
# Anitta - Anitta - 141817380 - True
# Luiz Inácio Lula da Silva - LulaOficial - 2670726740 - True
# Nikolas Ferreira - nikolas_dm - 758264276 - True
# Neymar Jr - neymarjr - 158487331 - True

# %%
BASE_URL_LAST_TWEETS = "https://api.twitterapi.io/twitter/user/last_tweets"

def coletar_textos_tweets_por_user_id(user_id):
    """
    Retorna uma lista de dicts {"text": "..."} para um único userId.
    NÃO faz retry interno de 429; assume que o chamador controla o intervalo.
    """
    uid_str = str(user_id)
    print(f"Buscando tweets para userId {uid_str}...")

    params = {"userId": uid_str}
    resp = requests.get(BASE_URL_LAST_TWEETS, headers=headers, params=params)

    print("Status code:", resp.status_code)
    print("Resposta bruta (início):")
    print(resp.text[:200])

    if resp.status_code == 429:
        print("Erro 429 (Too Many Requests). Chamadas estão muito rápidas.")
        return []

    if resp.status_code != 200:
        print(f"Erro {resp.status_code} para {uid_str}: {resp.text}")
        return []

    data = resp.json()
    bloco_data = data.get("data")
    if not bloco_data:
        print(f"Nenhum dado de tweets para userId {uid_str}: {data.get('msg')}")
        return []

    tweets = bloco_data.get("tweets", [])
    textos = []

    for t in tweets:
        if isinstance(t, dict):
            texto = t.get("text")
            if texto:
                textos.append({"text": texto})

    return textos

# %%
# Extrair apenas os userId válidos (não None)
def extrair_user_ids(contas_com_id):
    user_ids = []
    for c in contas_com_id:
        uid = c.get("id")
        if uid:  # ignora None ou vazio
            user_ids.append(uid)
    return user_ids

user_ids = extrair_user_ids(contas_com_id)

print("UserIds válidos:")
for uid in user_ids:
    print(uid)
# Out:
# UserIds válidos:
# 14128609
# 14213711
# 115678425
# 2203709322
# 738143559920934912
# 74756085
# 215282625
# 230186518
# 2329070186
# 451200058
# 815671379202887684
# 141817380
# 2670726740
# 758264276
# 158487331

# %%
def coletar_e_salvar_varios_users(user_ids):
    for uid in user_ids:
        tweets_textos = coletar_textos_tweets_por_user_id(uid)
        print(f"Total de tweets salvos para {uid}: {len(tweets_textos)}")

        # salvar_json é sua função já existente
        salvar_json(tweets_textos, sufixo=f"user_{uid}")

        # pausa de 5+ segundos para não disparar 429 no próximo user
        print("Aguardando 5 segundos antes do próximo userId...")
        time.sleep(5)

coletar_e_salvar_varios_users(user_ids)
# Out:
# Buscando tweets para userId 14128609...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993348432845849012","url":"https://x.com/felipeneto/status/1993348432845849012","twitterUrl":"htt
# Total de tweets salvos para 14128609: 18
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 14213711...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1992754128846528922","url":"https://x.com/DaniloGentili/status/1992754128846528922","twitterUrl":"
# Total de tweets salvos para 14213711: 19
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 115678425...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[]},"has_next_page":false,"next_cursor":"DAADDAABAAgAAgAAAAIIAAMAAAAACAAEAAAAAAoABRuqNSh4wCcQCgAGG6o1KHi_2PAAAA"}
# Total de tweets salvos para 115678425: 0
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 2203709322...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993342631087382709","url":"https://x.com/maisa/status/1993342631087382709","twitterUrl":"https://
# Total de tweets salvos para 2203709322: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 2238485718...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"410504924032540672","url":"https://x.com/LorenaOrsi/status/410504924032540672","twitterUrl":"https
# Total de tweets salvos para 2238485718: 4
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 738143559920934912...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993397903629729914","url":"https://x.com/ErikakHilton/status/1993397903629729914","twitterUrl":"h
# Total de tweets salvos para 738143559920934912: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 74756085...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993446219872714769","url":"https://x.com/BolsonaroSP/status/1993446219872714769","twitterUrl":"ht
# Total de tweets salvos para 74756085: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 215282625...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993399360105988295","url":"https://x.com/tiagosantineli/status/1993399360105988295","twitterUrl":
# Total de tweets salvos para 215282625: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 230186518...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993187056093106484","url":"https://x.com/whindersson/status/1993187056093106484","twitterUrl":"ht
# Total de tweets salvos para 230186518: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 2329070186...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1991556487681098056","url":"https://x.com/vinijr/status/1991556487681098056","twitterUrl":"https:/
# Total de tweets salvos para 2329070186: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 451200058...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993388264993308852","url":"https://x.com/cellbit/status/1993388264993308852","twitterUrl":"https:
# Total de tweets salvos para 451200058: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 815671379202887684...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993398858467151888","url":"https://x.com/RodrygoGoes/status/1993398858467151888","twitterUrl":"ht
# Total de tweets salvos para 815671379202887684: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 141817380...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":1,"msg":"user 141817380 not found","data":null}
# Nenhum dado de tweets para userId 141817380: user 141817380 not found
# Total de tweets salvos para 141817380: 0
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 2670726740...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993275903086825887","url":"https://x.com/LulaOficial/status/1993275903086825887","twitterUrl":"ht
# Total de tweets salvos para 2670726740: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 758264276...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993451963418394900","url":"https://x.com/nikolas_dm/status/1993451963418394900","twitterUrl":"htt
# Total de tweets salvos para 758264276: 20
# Aguardando 5 segundos antes do próximo userId...
# Buscando tweets para userId 158487331...
# Status code: 200
# Resposta bruta (início):
# {"status":"success","code":0,"msg":"success","data":{"pin_tweet":null,"tweets":[{"type":"tweet","id":"1993462597623202207","url":"https://x.com/neymarjr/status/1993462597623202207","twitterUrl":"https
# Total de tweets salvos para 158487331: 20
# Aguardando 5 segundos antes do próximo userId...

# %%
#@title Definição das listas com os textos que serão usadas para análise de sentimentos

# Uma lista separada para cada userId (se quiser separar por conta)
todas_listas = {}

for uid in user_ids:
    lista_textos = []
    sufixo = f"user_{uid}"          # mesmo sufixo usado em salvar_json
    carregar_json(lista_textos, sufixo)
    # lista_textos agora contém [{"text": "..."}] ou só strings,
    # dependendo de como você salvou

    # Se o JSON foi salvo como [{"text": "..."}, ...], converta para lista de strings:
    if lista_textos and isinstance(lista_textos[0], dict):
        textos_puros = [t.get("text", "") for t in lista_textos if t.get("text")]
    else:
        textos_puros = [str(t) for t in lista_textos]

    todas_listas[uid] = textos_puros

    print(f"\nTweets carregados para userId {uid}:")
    imprimir_lista(textos_puros)  # imprime cada texto

# Se quiser juntar tudo em uma única lista para análise de sentimento:
all_texts_gemini = []
for uid, textos in todas_listas.items():
    all_texts_gemini.extend(textos)
# Out:
# Tweets carregados para userId 14128609:
# Quantidade total de tweets: 18
# Tweet 1: 🌃 CIDADE DORME VIROU JOGO!
#
# A pré-venda de Cidade Dorme Netolab ESTÁ ABERTA e você não pode perder a oportunidade de ter o jogo físico na sua casa. Compre agora na promoção e ganhe duas cartas exclusivas!
#
# 🔗 Link: https://t.co/R53BVvTbCZ
#
# Tweet 2: O vídeo de hoje é uma volta às origens do canal!
#
# Quem lembra do “Tente Não Rir” e do “APEI”?
#
# Então…
#
# Assista: https://t.co/iSl2bKhDmV https://t.co/9UkTlsnS6J
#
# Tweet 3: Pra quem pergunta pq eu parei de usar o Twitter pra dar opinião…
#
# Repostei um texto do mais respeitado crítico de cinema do Brasil, dizendo q concordo com sua visão sobre o filme “Frankenstein”.
#
# Tive q ler um desgraçado responder com “Frankenstein é um livro medíocre e vcs só querem pagar de intelectuais”.
#
# Livro medíocre. O livro que inventou a ficção científica. O livro q mudou a literatura. O livro q 200 anos depois continua sendo um dos melhores já escritos, extremamente atual e maravilhoso. Escrito por uma mulher em pleno início do século 19! O livro… Apenas O livro!
#
# Esse é um dos principais motivos que parei de dar opinião nesta bosta, pq todo dia eu ficava lendo gente burra desse nível querendo farmar like. Hoje acabei cedendo, dei uma opinião e lembrei do esgoto q isso aqui virou.
#
# Tweet 4: Concordo com cada palavra, cada vírgula, cada espaço entre as letras.
#
# E aposto q isso ainda vai ser indicado a “melhor roteiro adaptado”, enfiando uma estaca na alma de Mary Shelley.
#
# Tweet 5: Mano
#
# Tweet 6: Vídeo extremamente necessário pros dias atuais:
#
# https://t.co/WeXOLoWsiW
#
# Aproveita, se inscreve no canal do Marcel e manda pros amigos! https://t.co/H1ZY6oPewP
#
# Tweet 7: O vídeo de hoje tá diferente de tudo que a gente já fez em 15 anos de canal!
#
# Assista: https://t.co/MIZEyxQlNF
#
# Gostou? Mande o link pra um amigo! https://t.co/s0amH4Q6eC
#
# Tweet 8: O vídeo do @brauneoficial do dia em que vimos Cabo Verde ir pra Copa do Mundo ficou ABSURDO!
#
# Pra quem viu Netour, esse é um outro ponto de vista muito bom.
#
# Assista: https://t.co/DbVZOJBh1N https://t.co/4K5XTK2mnE
#
# Tweet 9: Absurdo!
#
# Tweet 10: 🏆 PRÊMIO INTERNACIONAL!
# Em uma sátira inspirada em 1984, anunciei minha “candidatura à presidência” — e MUITA gente surtou com isso 🤣
# Mas, claro… era uma ação minha com a Audible!
#
# A campanha foi indicada ao OMMA Award, em Nova York!
#
# Nossa categoria era “Criatividade em Publicidade Online”, competindo lado a lado com campanhas do McDonald’s 🍟 e de The White Lotus 🏝️
# E lá estávamos nós: Audible + Agência Live + Play9 + Felipe Neto.
#
# E NÓS VENCEMOS! 🥇
#
# Mas não parou aí…
# Entre as 58 categorias e centenas de cases no mundo todo, nossa campanha foi eleita o “Best in Show” — ou seja, o MAIOR PRÊMIO DO ANO! 🎖️
#
# Muito, muito, muito orgulho!
# Foram +500 milhões de impressões, 2,6 milhões de engajamentos e um aumento de 316% nas visitas ao site da Audible.
#
# 🙏 Obrigado @livetheagency, @MediaPost, Play9, Audible…
# E também à @netolaboficial e ao Marcel, que escreveu esse roteiro comigo ❤️
#
# Tweet 11: 🔴 ESTÁ NO AR!
#
# Netour - Cabo Verde
#
# EU VI O CRISTIANO RONALDO
#
# Extremistas, entendam: Trump e Bolsonaro não são o capitalismo. Eles representam a sua pior face.
#
# O fato de ter críticas contundentes ao Trump não tem qualquer ligação com visitar os EUA. Imagine só poder pisar em um país se você for admirador do atual presidente em vigor. Seguindo essa lógica, quase todos os que me atacam deveriam então abandonar o Brasil.
#
# Curiosamente, quem propaga essa visão excludente e proibitiva são exatamente os que gritam defender a tal “liberdade”. Imagine se Biden ou Obama perseguissem conservadores e retirassem seus vistos, deportassem suas famílias, ao mesmo tempo em que usuários progressistas nas redes sociais ficassem denunciando cada conservador, suas localizações e pedindo para que fossem expulsos. Quem recebe educação básica jamais defenderá isso, pois sabe que um presidente não é dono do seu país. E nem das joias que recebe de presente como Chefe de Estado.
#
# Falando em educação, gostaria de dizer que não poderia ter sido melhor recebido pelas pessoas por todos os lugares por onde passei, tanto na Flórida quanto em Nova York. Receber o carinho de vocês é sempre extraordinário. E tirando um único covarde que esperou estar longe para gritar “aproveitando o capitalismo, né?” em um parque, ao que foi completamente ignorado, todas as demais interações foram incríveis e carinhosas.
#
# Vou continuar viajando para onde bem entender e usufruindo do sistema econômico no qual estou inserido. Isso se chama “vida real”. Vivo o capitalismo no Brasil, sou financeiramente bem sucedido nele e isso não me impedirá de lutar contra seus profundos problemas, principalmente sua grotesca desigualdade social. Desigualdade essa que não está nas bolsas de grife e viagens de primeira classe, mas no fato de menos de 10 bilionários no Brasil acumularem aproximadamente a mesma fortuna dos 100 milhões de brasileiros mais pobres somados.
#
# (1/3) Continua no próximo post >>
#
#
# Tweets carregados para userId 14213711:
# Quantidade total de tweets: 19
# Tweet 1: RT @ajulysantos: O @BolsonaroSP diz que, politicamente, Lula solto é muito melhor porque fortaleceria o antipetismo.
#
# A arrogância dele não…
#
# Tweet 2: Xadrez 20 mil D https://t.co/S2miaeqncI
#
# Tweet 3: RT @MauMeirelles: Eu sei que vcs torcem contra todo mundo.
# Mas essa notícia, infelizmente, é mentira.
#
# O programa não acabou, não há derrot…
#
# Tweet 4: RT @aguedescartoon: INCÊNDIO na COP30 https://t.co/OsxVzGPgXt
#
# Tweet 5: Parabéns @BolsonaroSP 👏👏👏 https://t.co/5NzhtCql9O
#
# Tweet 6: https://t.co/GnAEt04Mys
#
# Tweet 7: Se você que sumir, fale com o Patati.
# Se você quer chorar, fale com o Patatá.
#
# Tweet 8: Po bicho,
# Mas como ele iria falar com uma raquete de ping pong  na boca? https://t.co/T0S7vRDgLT
#
# Tweet 9: Boa noite, pessoal
#
# Tweet 10: Isso aí. SC não é curral eleitoral.
#
# Tweet 11: O Carlos não mudou a ladainha do gabinete do ódio até hoje. Ainda é “cara você tá passando vergonha “ “SBT demita ele” “ele tem inveja do mito” tá muito 2018 isso aí, dá uma melhorada.
#
# Tweet 12: Se um fdp apontar um revólver na sua cara e apertar o gatilho mas for incompetente o bastante para errar o tiro , ele pode voltar depois e dizer “mas você está morto? Não. Então eu não sou um assassino”
#
# Tweet 13: Se pesquisar encontrará coisas ainda piores que isso . Recentemente Carlos Bolsonaro , por exemplo, fez isso: https://t.co/wqarWjSn95
# Tweet 19: No mês da Consciência Negra, a vereadora do PSOL Eliete Paraguassu, primeira quilombola eleita em Salvador,  está sendo perseguida por fazer exatamente o que uma representante pública deve fazer: defender os direitos dos professores e denunciar o racismo na Câmara de Salvador.
#
# Tudo começou na sessão em que os vereadores da base do prefeito Bruno Reis votaram, a portas fechadas, o projeto que desmontava o Plano de Cargos e Salários dos professores da rede municipal, que estavam em greve. Eliete estava na defesa dos trabalhadores quando o vereador Cláudio Tinoco a atacou, dizendo que “o lugar de Eliete não era ali” e que "o lugar dela era lá fora".
#
# Uma fala racista, elitista e misógina, que mostrou o incômodo deste vereador com mulheres negras ocupando espaços de poder.
#
# Eliete fez o que precisava ser feito: denunciou o ataque na tribuna e na Delegacia de Crimes Raciais. Mas, em vez de proteger a vítima, a Câmara abriu um processo contra ela no Conselho de Ética. A velha estratégia de inverter papéis para tentar silenciar quem denuncia o racismo.
#
# Isso não é um caso isolado.
# Mulheres negras eleitas em todo o Brasil enfrentam ataques quando chegam a espaços que sempre lhes foram negados.
#
# Por isso afirmamos: Eliete não está só e não ficará.
#
# #ElieteNãoEstáSó
#
# Tweet 20: 🚔 BOAS NOTÍCIAS
#
# O senador @_AlessandroSE, relator do Projeto Antifacção no Senado, afirmou que modificará o Projeto para proteger a Polícia Federal
#
# O texto, aprovado ontem na Câmara, na prática, impede que a PF apreenda bens do crime organizado e os use no combate às facções.
#
# Além disso, ele dizima os recursos dos fundos que financiam as investigações e operações e cria vícios jurídicos que acabam protegendo o andar de cima do crime organizado. Protege os criminosos que não estão nas favelas, mas sim na Faria Lima e na política.
#
# Felizmente, o senador Alessandro Vieira também afirmou que pretende produzir um novo texto realizando audiências públicas, ouvindo os especialistas e eliminando qualquer tipo de falha técnica. Contamos com você, senador!
#
#
# Tweets carregados para userId 74756085:
# Quantidade total de tweets: 20
# Tweet 1: Sem o mínimo potencial para ser um golpe de Estado, aquilo que a história registrará como o golpe da Disney ainda está longe de terminar.
#
# Por ter sido um julgamento político, ele instigará o cenário político a mudar e corrigir esta bizarrice alexandrina. Podem anotar. https://t.co/GemwNqF157
#
# Tweet 2: Pode anotar, a tendência é cada vez mais e mais fatos como este ocorrerem.
#
# Sanção é um instrumento burocrático, que leva certo tempo para ser processado, mas cada vez mais e mais seus efeitos serão sentidos pelo atingidos. Quem fala que "a sanção não pegou no Brasil" engana-se.
#
# Tweet 3: RT @pfigueiredo08: As maiores vítimas do estelionato diplomático praticado por Lula e Mauro Vieira foram os diversos setores que ficaram de…
#
# Tweet 4: A mensagem direta de @jairbolsonaro para @HugoMottaPB e @davialcolumbre.
#
# *Via @FlavioBolsonaro https://t.co/5foM19VosQ
#
# Tweet 5: Moras fala em "fake news" e não aponta a mentira; acusa de milícia digital e não nomeia os integrantes; diz que tentaram um golpe e não expõe as armas... é tudo 100% narrativa.
#
# Tweet 6: Preste atenção em quem está fora do Brasil vivendo em países livres. Estas são as principais fontes, que têm mais liberdade para lhe contar a verdade - que nem sempre é falada no Brasil e, assim, acaba embaralhando a sua visão.
#
# Siga @delegadoramagem e outros, tenha clareza do cenário para ter claro também o seu norte, o seu objetivo.
#
# Tweet 7: Brazil's supreme court learned with Trump's election in U.S. that they cannot let Bolsonaro run in 2026 election
#
# So they arrested Bolsonaro, not because criminal reasons, but political
#
# The mess left behind by Biden administration, a powerful Moraes now is kidnaping Brazil
#
# 🎥 @Bannons_WarRoom
# Full: https://t.co/1QX7SaKIsO
#
# Tweet 8: PRIMEIRO CIRA-SE CONSCIÊNCIA, DEPOIS VEM AS AÇÕES EXECUTIVAS
#
# -Moraes quer assassinar Bolsonaro, tal qual Clezão;
# -O futuro de Trump e outros líderes da direita;
# -O que pode ser feito para o Brasil?
#
# 🎥 @Bannons_WarRoom . Completo:
# https://t.co/ZadhuDcoop https://t.co/KsKOHmYxVa
#
# Tweet 9: Um requisito básico e muitíssimo comum para ingressar nestas gangues/pandilhas - e então ser tatuado - é matar 10 pessoas
#
# Nesta última visita vi pessoas que mataram grávida com machadinha, atearam fogo em ônibus com trabalhadores dentro e etc. Esta gente está neste vídeo. E o povo reelegeu quem os colocou neste vídeo -  @nayibbukele - com 84%.
#
# Tweet 10: Here is an overview of what is happening in Brazil regarding Bolsonaro’s bizarre arrest and the persecution against the right.
#
# It is the same virus as in the U.S., and if it is not fought globally too, it will only continue to grow stronger.
#
# 🎥 @Bannons_WarRoom
# https://t.co/UEOyTi7Bna
#
# Tweet 11: The Brazilian people are already very grateful to Pres. @realDonaldTrump and have expressed this in recent street demonstrations, carrying signs in English with that message of appreciation.
#
# However, considering the application of the Magnitsky Act, as an expression of justice, against those who support abuses by justice Moraes, would also help curb the authoritarian momentum of these Brazilian authorities, who disregard freedoms and violate U.S. laws.
#
# 🎥 @Bannons_WarRoom today morning.
# https://t.co/UEOyTi73xC
#
# Tweet 12: RT @mfriasoficial: SOMOS TODOS BOLSONARO! https://t.co/ipDqOAkZtq
#
# Tweet 13: RT @CarlosBolsonaro: Bolsonaro sobreviveu a uma facada, sobreviveu a ataques de todos os tipos e nunca cedeu, nunca desistiu, nunca se curv…
#
# Tweet 14: Some disturbing reality about Bolsonaro's preventely arrest yesterday by the psychopath supreme court justice Alexandre de Moraes, the same who banned X, Rumble and Telegram from Brazil.
#
# Thank you for the opportunity @Bannons_WarRoom 🙏
#
# Full:
# https://t.co/luxXSGN77G https://t.co/KroRzP0446
#
# Tweet 15: RT @CarlosBolsonaro: - In the history of the world, the gravest injustices have never endured. Evil always meets its answer, and no cycle e…
#
# Tweet 16: Sensacional homenagem. Mas do que nunca é preciso expor, falar e denunciar a ditadura de toga do Brasil.
#
# Deus quiser vamos virar esta página e, mais forte retornaremos a botar o interesse do brasileiro em primeiro lugar.
#
# Tweet 17: This is what the left expect for the future of
# 🇺🇸@realDonaldTrump
# 🇫🇷@MLP_officiel
# 🇦🇷@JMilei
# 🇸🇻@nayibbukele
# 🇮🇱@netanyahu
# 🇮🇹@matteosalvinimi
# and any other rightwing politician.
#
# They are becoming more and more agressive. As they act globally, we have to fight back globally too. https://t.co/t39kFWbEN4
#
# Tweet 15: RT @GORILLAZ1962: A língua é o chicote III https://t.co/5WIwbvT6kd
#
# Tweet 16: RT @PaulinhoSerra: Esse cara que só usou palavras apanhou mais que ADÉLIO BISPO que deu uma facada e foi defendido por vários homem com toa…
#
# Tweet 17: mamis estava certa sempre
#
# Tweet 18: RT @GuedinhoeFans: Isso foi simplesmente insano. O cara pegou o microfone e falou na cara de um bando de extremistas, sem tremer, como uma…
#
# Tweet 19: RT @1fabiogomes: A tornozeleira falando igual a máscara do Duende Verde
#
# GRANDE DIA https://t.co/k0c6LC9EJA
#
# Tweet 20: RT @cortezpsol: Nem todo heroi usa capa. https://t.co/nPngCRHvfA
#
#
# Tweets carregados para userId 230186518:
# Quantidade total de tweets: 20
# Tweet 1: É o ciclo, arrependimentos e tudo mais, mas logo vc tá cheia de energia de novo!
#
# Tweet 2: Fizemos a vibe em Teresina! Foi gostosinho demais,  e quente! 🔥 https://t.co/I0cnoMGLBp
#
# Tweet 3: Boa madrugada gentee
#
# Tweet 4: Marquei com uma dentista nos Tocantins, agora ela não pode mais me atender pq tá namorando, diabéisso
#
# Tweet 5: 🤏🏽🥹 https://t.co/EQQhinowlc
#
# Tweet 6: RT @whindersson: Meu pronunciamento 🫵🏻
#
# https://t.co/jDVoYJNrHy https://t.co/GhPMumJZTo
#
# Tweet 7: Ei @toguro cadê minha touca
#
# Tweet 8: Meu pronunciamento 🫵🏻
#
# https://t.co/jDVoYJNrHy https://t.co/GhPMumJZTo
#
# Tweet 9: https://t.co/eLJ2wv8Tzn
#
# Tweet 10: Gosto de estar de madrugada por aqui porque os robôs de brigas de  polaridade parece que tao desligados kkkkkkkkkkk
#
# Tweet 11: Foi pressão, a palavra foi levada
#
# Tweet 12: E o show em Teresina tá flopado, mas agora é ser estoico, levar o melhor show e vibe
#
# Tweet 13: Maria
#
# Tweet 14: https://t.co/diYozmPIye
#
# Tweet 15: Interceder sem interferir - Djavan
#
# Tweet 16: https://t.co/1QcEWwbiEW
#
# Tweet 17: https://t.co/bsjtsV1y42
#
# Tweet 18: https://t.co/I47OZnCCLk
#
# Tweet 19: https://t.co/nAUzk7oTOH
#
# Tweet 20: https://t.co/QFFxpwVEsf
#
#
# Tweets carregados para userId 2329070186:
# Quantidade total de tweets: 20
# Tweet 1: Bold. Balanced. Fresh.
# Boss Bottled Beyond is my go to fragrance.
#
# #BOSSrecognizeBOSS https://t.co/59qu955RaY
#
# Tweet 2: always @Prada 🫡
#
# #prada #pradaeyewear https://t.co/Tp2VCpVydx
#
# Tweet 3: Hoy quiero pedir disculpas a todos los madridistas por mi reacción al ser sustituido en el Clásico.
#
# Así como ya lo he hecho en persona durante el entrenamiento de hoy, también quiero pedir disculpas nuevamente a mis compañeros, club y presidente.
#
# A veces la pasión me gana por querer siempre vencer y ayudar a mi equipo. Mi carácter competitivo nace del amor que siento por este club y por todo lo que representa.
#
# Prometo seguir luchando cada segundo por el bien del Real Madrid, como lo he hecho desde el primer día. 🤍  @realmadrid
#
# Tweet 4: https://t.co/NccnvY8AC4
#
# Tweet 5: LA ✨ https://t.co/KUq5YQggE1
#
# Tweet 6: https://t.co/GEhEdMfUnq
#
# Tweet 7: https://t.co/Og1KnF1nUJ
#
# Tweet 8: Bem vindo, MISTER!! Vamos juntos, BRASIL!!!!! 🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧�
# Especificamente, se rolasse essa perseguição, o resultado dos 3 sucessos sempre seria o carro dos Couraças aparecendo e livrando eles do Quibungo. Eles tinham a escolha de entrar no carro, como fizeram, ou ignorar e ir embora - se fizessem isso, o Quibungo ia correndo atrás do carro, afinal, ele é consideravelmente mais barulhento e maior, e os jogadores ficariam seguros também.
#
# E, pra finalizar...
#
# ESCARLATA, JAE E LABIRINTO
# Não, eu não vou fazer um "raio-x" dessa cena. NÃO ADIANTA PEDIR.
#
# Tweet 4: https://t.co/m9p54kbppc
#
# Tweet 5: RT @OrdemParanormal: O #HEXATOMBE ESTÁ COMEÇANDO AGORA!
#
# Acompanhe na plataforma que preferir:
#
# 🔴YOUTUBE (4k)
# https://t.co/squYJ5Hvxz
#
# 🟣TWI…
#
# Tweet 6: se preparem.
#
# Tweet 7: os primeiros 3 episódios eram só o tutorial
#
# Tweet 8: obrigado mais uma vez pelo apoio nessa temporada.
#
# hexatombe tem sido um dos maiores desafios pra toda a equipe, e eu não poderia estar mais orgulhoso até agora.
#
# especificamente essa temporada, pela temática, é praticamente impossível vender qualquer patrocínio. todas as marcas interessadas deram pra trás assim que leram a premissa dos acontecimentos da temporada.
#
# o que significa que todo o orçamento dessa temporada (que é disparado a mais cara até agora) tá saindo direto do meu bolso mesmo
#
# a única fonte de renda pra essa temporada são os nossos produtos originais (livros, quadrinhos, merch, subs, etc.)
#
# sempre fui aberto que o Ordem é um projeto que não se paga, e eu sempre tirei do meu próprio bolso pra conseguir pagar a equipe toda, mas os patrocinadores dos episódios definitivamente eram uma parte importante que não é possível pra essa
#
# mesmo com isso tudo, é graças a esse projeto que:
# - eu consigo pagar uma equipe de mais de 30 artistas e programadores brasileiros
# - sem uso de IA
# - sem patrocínio de cassino e golpe
# - milhões de pessoas se divertem todo sábado
# - incentiva uma comunidade inteira de novos artistas e escritores criando o próprio conteúdo fanmade
# - meus amigos se divertem jogando e participando
# - consigo dar holofote a artistas e criadores menores alcançarem mais público
# - eu realizo meu sonho de infância de viver criando histórias
#
# qualquer ponto negativo, como críticas insensíveis sobre a produção/equipe como se fosse uma empresa bilionária, ou algumas pessoas amarguradas viralizando clipes fora de contexto porque acham "cringe" é definitivamente esmagado por quanto eu amo isso
#
# aqueles que desperdiçam a própria vida obcecados em como são enxergados pelos outros nunca vão conseguir experienciar o que é realmente viver por completo
#
# obrigado mais uma vez, essa temporada tá do caralho, e espero que continuem curtindo tanto quanto a gente ♥
#
# Tweet 9: Bem vindos ao Hexatombe.
#
# Tweet 10: pessoal nao sei se foi uma boa ideia
#
# vendo ingresso show do psikolera agorinha aparece aqui rapidao the monica club
#
# Tweet 11: é hoje https://t.co/dbYcwMBgWQ
#
# Tweet 12: compro ingresso show do psikolera pista the monica club amanhã DM para propostas
#
# Tweet 13: pari os 3
#
# Tweet 14: Espero que tenham gostado do primeiro episódio de #HEXATOMBE.
#
# É só o começo. Vocês não fazem ideia.
#
# Nos vemos sábado que vem.
#
# Tweet 15: aparentemente quebramos o recorde de novo.
#
# #HEXATOMBE é a transmissão de RPG mais assistida do mundo
#
# sem palavras. muito obrigado.
#
# Tweet 16: é claro https://t.co/cBkBm6BJAO
#
# Tweet 17: é hoje.
#
# Tweet 18: #NovaFotoDePerfil https://t.co/RkEJ6FjmpK
#
# Tweet 19: ansioso pra outubro
#
# Tweet 20: Jogar Silksong foi como voltar para casa.
#
# Esse jogo é exatamente tudo que eu esperava, e mais.
#
# É difícil pontuar um motivo exato do que faz esse jogo tão especial, porque ele é uma obra de sutilezas. Uma construção de pequenos detalhes tecendo uma identidade tão própria que é quase como se o jogo tivesse uma personalidade.
#
# Cada pequeno canto esconde um segredo, uma descoberta, um novo momento que te lembra o quanto ele é especial.
#
# Depois de mais de 80 horas explorando Fiarlongo, apanhando pra bosses, rindo com NPCs, odiando o Bilebrejo e tentando desvendar o máximo de lore, eu tenho certeza que, assim com Hallownest, esse é um lugar que vai me acompanhar por muitos anos.
#
# Silksong é a sequência perfeita pra Hollow Knight, porque ele consegue ser tudo que o primeiro não é.
#
# A trajetória do Knight é uma de declínio, literal e narrativamente. É uma jornada sobre colocar o ponto final em um mundo que já acabou muito antes de você entrar nele. Um jogo sobre ser verdadeiramente vazio.
#
# ...
#
# 📸 @ricardostuckert
#
# Tweet 13: Presidente Lula conversa com a imprensa em Joanesburgo https://t.co/Q3ldAHTZ2m
#
# Tweet 14: 📝 Discurso do presidente Lula na terceira sessão da Cúpula de Líderes do G20
#
# Compartilhamos um momento histórico em que os minerais críticos, a inteligência artificial e o trabalho se entrelaçam com intensa singularidade. A forma como nós integrarmos esses três vetores do desenvolvimento definirá não apenas o nosso presente, mas o futuro das próximas gerações. Os minerais críticos se tornaram um ativo central para a geopolítica contemporânea. Eles são fundamentais não só para o desenvolvimento das tecnologias de ponta, mas também para a transição energética.
#
# O setor de energia foi responsável por 85% do crescimento total da demanda por esses minerais em 2024. Não há como honrar o compromisso de triplicar o uso de renováveis sem incluí-los.
#
# A transição energética abre oportunidades para ampliar as fronteiras tecnológicas a serviço da humanidade. Mas também oferece a chance de ressignificar o papel da exploração dos recursos naturais.
#
# Os países com grande concentração de reservas de minerais não podem ser vistos como meros fornecedores, enquanto seguem à margem da inovação tecnológica. O que está em jogo não é apenas quem detém esses recursos, mas quem controla o conhecimento e o valor agregado que deles derivam.
#
# Falar sobre minerais críticos também é falar sobre soberania. A soberania não é medida pela quantidade de depósitos naturais, mas pela habilidade de transformar recursos através de políticas que tragam benefícios para a população. Precisamos de investimentos ambientalmente e socialmente responsáveis, que contribuam para fortalecer a base industrial e tecnológica dos países detentores de recursos.
#
# O Brasil criou o Conselho Nacional de Minerais Críticos e Estratégicos. Não seremos apenas exportadores, e sim parceiros na cadeia global de valor de minerais críticos.
#
# 📸 @ricardostuckert
#
# Tweet 15: Participei hoje da Cúpula de Líderes do IBAS, um Fórum de Diálogo entre Índia, Brasil e África do Sul, junto com o Primeiro-Ministro @narendramodi e o presidente @CyrilRamaphosa.
#
# O IBAS nasceu como um importante foro de coordenação de três grandes democracias e economias do Sul Global. Índia, Brasil e África do Sul têm a vocação de conciliar os valores de soberania e autonomia com a busca por desenvolvimento e com a defesa da democracia e dos direitos humanos.
#
# Essa capacidade, que está em falta no mundo de hoje, é a marca do IBAS e nossa maior contribuição para a ordem internacional. Compartilhamos muitas causas e temos muito a dizer para o mundo. Defender a agenda multilateral de saúde e o debate sobre acesso a medicamentos, vacinas e insumos é uma trilha que o IBAS deve explorar.
#
# Entre nós três é possível dialogar abertamente sobre direitos humanos, equidade de gênero e direitos sexuais e reprodutivos. Há confiança para discutir o combate ao extremismo e a defesa da democracia. Sindicatos e ONGs organizados e vibrantes nos inspiram a debater a participação social e os dilemas do mundo do trabalho em mercados emergentes. Nossos países são chave para a construção de um sistema justo, democrático e funcional de governança e acesso a dados. Temos condições para estar na vanguarda da governança global da Inteligência Artificial.
#
# A vocação do IBAS para a cooperação Sul-Sul também segue viva. O Fundo IBAS é uma iniciativa simples e eficaz. Desde sua criação, já financiou 51 projetos em 40 países. E foi um dos precursores da Aliança Global contra a Fome e a Pobreza que lançamos no G20 ano passado.
#
# O encontro de hoje é um passo central para reavivar nossa coordenação trilateral 🇮🇳🇧🇷🇿🇦
#
# 📸 @ricardostuckert
#
# Tweet 16: Lula discursa na sessão "Um Futuro Justo para Todos", durante o encontro da Cúpula do G20 https://t.co/u1sY2qwIr9
#
# Tweet 17: O debate sobre a tributação internacional e a taxação dos super ricos é inadiável. Está na hora de declarar a desigualdade como emergência global. A desigualdade extrema representa um risco para todas as economias.
#
# O G20 deve incentivar a adoção de mecanismos inovadores de troca de dívida por desenvolvimento e ação climática.
#
# 🎥 Audiovisual/PR
#
# Tweet 18: G20 2025: Solidariedade, Igualdade e Sustentabilidade 🌐
#
# 📸 @ricardostuckert https://t.co/Tl4zFLenp0
#
# Tweet 19: 📝 Discurso do presidente Lula na segunda sessão da Cúpula do G20
#
# Esta oportuna sessão ocorre no mesmo tempo em que estamos por duas palavras de concluirmos as negociações da COP30 no Brasil.
#
# No ano em que o planeta ultrapassou pela primeira vez – e talvez de forma permanente – o limite de um grau e meio acima dos níveis pré-industriais, a comunidade internacional tinha diante de si uma escolha: continuar ou desistir.
#
# Optamos pela primeira alternativa.
#
# Na COP da verdade, a ciência prevaleceu. O multilateralismo venceu. Reafirmamos nosso compromisso com o Acordo de Paris. Saímos de Belém com um quadro renovado de Contribuições Nacionalmente Determinadas. Mobilizamos a sociedade civil, a academia, o setor privado, os povos indígenas e os movimentos sociais, para fazer da COP30 a COP com a segunda maior participação da história.
#
# Entramos agora numa nova etapa, que exigirá esforço simultâneo em duas frentes: acelerar as ações de enfrentamento da mudança clima, e nos preparar para uma nova realidade climática.
#
# O G20 cumpre papel central em ambas. O grupo responde por 77% das emissões globais. É do G20 que um novo modelo de economia deve emergir. O grupo é um ator-chave na elaboração de um mapa do caminho para afastar o mundo dos combustíveis fósseis.
#
# 📸 @ricardostuckert
#
# Tweet 20: Me reuni hoje com o chanceler da Alemanha, Friedrich Merz, à margem da reunião do G20 em Joanesburgo, na África do Sul.
#
# Tweet 11: Posição correta do X. Estou sendo processado e perseguido por REVIDAR uma frase que a esquerda levantou (PL - Partido de Ladrões) e postei, portanto, PT- Partido dos traficantes. A “justiça” foi atrás somente de um para retirar o post e aplicar multa. Nem disfarçam. Canalhada
#
# Tweet 12: +3hrs de autógrafos e muito carinho. Vale a pena! Obrigado, Floripa 👍🏻 https://t.co/n9QYxDLNJr
#
# Tweet 13: Se esse vídeo sumir, você já sabe o motivo. https://t.co/KACdETLXeH
#
# Tweet 14: RT @Frontieresmedia: « Les Sleeping Giants font la promotion de la persécution. Il est malheureux que Leroy Merlin cède »
#
# 🚨 La polémique L…
#
# Tweet 15: My appearance in the french media outlet @Frontieresmedia, commenting on the persecution and attempted censorship they have faced by Sleeping Giants, in the same way it happens in Brazil.
#
# 🇫🇷 Ma participation dans le média français Frontières, commentant la persécution et la tentative de censure qu’ils ont subies de la part de Sleeping Giants, de la même manière que cela se produit au Brésil.
#
# Tweet 16: O evento que era pra cuidar do meio ambiente tá pegando fogo kkkkkkkk ah coe
#
# Tweet 17: Matéria do Diário El Salvador @elsalvador América Latina será transformada. Se Deus quiser https://t.co/rxavtaGP2L
#
# Tweet 18: Alô, SC! É amanhã. Te espero lá 🙌🏻🩵🩷 https://t.co/bN11j4hV6B
#
# Tweet 19: 2 anos da morte de Clezão. E ainda hoje me lembro quando fui em seu velório, e sua filha me disse para não deixar a morte do seu pai em vão. Desde lá, foram manifestações, vídeos, documentário, CPMI, ocupação da mesa e articulação interna. Aprovamos a urgência, sob forte ataque- já que transfomaram a PEC das prerrogativas em outra coisa. Sofremos calados, mas o objetivo era maior. Estamos seguindo. É uma luta contra gigantes. E creio que, em breve, faremos justiça. Que Deus nos abençoe pra que isso ocorra o mais rápido possível e que os responsáveis por tirar o pai dessa família (que inclusive se mantém forte, humilde e sempre com um sorriso no rosto) sejam colocados atrás das grades.
#
# Tweet 20: Isso porque o Bolsonaro está em casa, senão a culpa do incêndio era dele.
#
#
# Tweets carregados para userId 158487331:
# Quantidade total de tweets: 20
# Tweet 1: RT @Pele: Alguns jogadores marcam épocas. Poucos mudam o jogo. Pelé mudou o mundo.
#
# Sua camisa, seus gols e sua magia ultrapassaram frontei…
#
# Tweet 2: Atenção pra dica: Se a grana tá curta… nem abre o app. Aposta é diversão, não investimento. Só faz sentido quando não te atrapalha. Use apenas o dinheiro que não vai fazer falta, como lazer.
# A aposta é imprevisível, e é isso que emociona… mas o jogo responsável deve estar sempre em primeiro lugar! E lembre-se: apenas para maiores de 18 anos.
#
# Saiba mais sobre jogo responsável com a @blazebetbr aqui 👉 https://t.co/1O4K6tA7n8
#
# ⚠ Jogue com responsabilidade. Não há garantia de ganhos. Apenas para maiores de 18 anos. Autorização SPA/MF nº 471
#
# Tweet 3: A galera foi fominha e não deixou sobrar nenhum snack da Canção para mim!
#
# #MinhaResenhaCanção #CançãoAlimentos #MomentoCanção https://t.co/J7JRoMMJdy
#
# Tweet 4: Quer testar um jogo novo, mas não sabe exatamente como funciona?
# Assim como no futebol a gente estuda o adversário antes de entrar em campo, e na @blazebetbr você também pode se preparar antes de apostar.
#
# É só conferir a Tabela de Pagamentos! Ela mostra tudo: valores, regras, bônus e cada detalhe do jogo — tudo bem claro, sem mistério. Porque transparência é coisa séria pra Blaze. ⚽🔥
#
# Com informação, você joga com responsabilidade.
# E lembre-se: apenas para maiores de 18 anos.
#
# ✅ Depósitos e saques via Pix
# 🎯 Diversão na medida certa
# 📲 Acesse: https://t.co/60i2H4IRmm
#
# ⚠ Jogue com responsabilidade. Não há garantia de ganhos. Apenas para maiores de 18 anos. Autorização SPA/MF nº 471
#
# Tweet 5: sou SANTOS pra Kr!@ 🤍🖤 https://t.co/40bUnkFDCc
#
# Tweet 6: Que final de semana 😍
# Fúria Kings league
# Santos FC
# Furia Cs
#
# Hat trick 😉🙏
#
# Tweet 7: Você já sabe, comigo é assim, hein?
# Os melhores momentos sempre envolvem Canção na resenha!
#
# #CançãoAlimentos #CadaMomentoUmaHistória https://t.co/XZiTEkMihO
#
# Tweet 8: https://t.co/4nnuPFyTZZ
#
# Tweet 9: Girou, lançou! 🎉
#
# Quando os Lança Confetes @PopperBrasil e Neymar Jr. entram em campo, a festa se torna inesquecível. ⚽😎
#
# Bora garantir o seu? Compre agora: https://t.co/g5flu61Qck
#
# #PopperBrasil #NeymarJr #LancaConfetePopperENeymarJr https://t.co/gekZvBTJRH
#
# Tweet 10: Thank you @Konami !!
#
# eFootball x Yu-Gi-Oh!
# #eFootballYuGiOhCollab https://t.co/hwN4gHTfUd
#
# Tweet 11: Good Vibes 😉 https://t.co/9975DMTj3N
#
# Tweet 12: Loading!!! @REPLAY https://t.co/hiRVjoJtoS
#
# Tweet 13: Muita gente acha que todos os jogos na @blazebetbr são criados pela própria Blaze — mas o catálogo é gigantesco e reúne os melhores provedores do mundo.
#
# Na https://t.co/60i2H4JpbU, você encontra títulos famosos como a série Fortune da PG Soft, a série Bonanza da Pragmatic Play, e os incríveis jogos ao vivo da Evolution, como Crazy Time e Monopoly. Todos certificados, seguros e aprovados por órgãos reguladores internacionais.
#
# 💡 Se tá na Blaze, é porque passou no teste! A plataforma só oferece jogos que garantem qualidade, transparência e segurança.
#
# ✅ Depósitos e saques via Pix
# 🎯 Diversão na medida certa
# 📲 Acesse: https://t.co/60i2H4JpbU
#
# ⚠ Jogue com responsabilidade. Não há garantia de ganhos. Apenas para maiores de 18 anos. Autorização SPA/MF nº 471
#
# Tweet 14: Minha dica para você amassar hoje são os snacks de Canção.
# Olha só, são a minha cara. 🤣
#
# #CançãoAlimentos #DicaDeAmigoCanção https://t.co/6WkXbaBWO8
#
# Tweet 15: Tem que profissionalizar a arbitragem no brasil pra ontem !
#
# Tweet 16: Virou rotina 🤣😜
#
# Tweet 17: Dia de clássico alvinegro na vila 🤍🖤 https://t.co/xlGvz10bMp
#
# Tweet 18: Quando o assunto é diversão online, é preciso segurança e responsabilidade!
#
# A @blazebetbr tem licença oficial do Governo Brasileiro, seguindo todas as exigências regulatórias. Isso significa regras claras, proteção ao jogador e compromisso com o Jogo Responsável. Pode conferir você mesmo. ✅
#
# Diversão com responsabilidade também exige estrutura e transparência.
# 👉 Escolha uma plataforma licenciada. Escolha https://t.co/60i2H4IRmm
#
# ⚠ Jogue com responsabilidade. Não há garantia de ganhos. Apenas para maiores de 18 anos. Autorização SPA/MF nº 471t
#
# Tweet 19: It's time to duel!
# The collaboration between eFootball™ and Yu-Gi-Oh! is now live!
# .
# É hora do duelo!
# A colaboração entre eFootball™ e Yu-Gi-Oh! já está no ar!
# #eFootball https://t.co/D0nTCFnRtd
#
# Tweet 20: Bora fazer pinta de craque na festinha?
# O Pinta Cabelo Popper e Neymar Jr. chegou em 11 cores para todas as ocasiões! ✨
# E é o 1º Pinta Cabelo do Brasil clinicamente testado.
# Que tal garantir o seu?
# #Popper #NeymarJr #PintaCabeloPopperENeymarJr https://t.co/6VXu0Vzjii

# %%
#@title Processando cada tweet

resultados_sentimentos = []
processando_tweets(all_texts_gemini, resultados_sentimentos)

# %%
print(resultados_sentimentos)
# Out:
# [{'tweet': '🌃 CIDADE DORME VIROU JOGO!\n\nA pré-venda de Cidade Dorme Netolab ESTÁ ABERTA e você não pode perder a oportunidade de ter o jogo físico na sua casa. Compre agora na promoção e ganhe duas cartas exclusivas!\n\n🔗 Link: https://t.co/R53BVvTbCZ', 'categoria': 'positivo', 'sentimentos': ['felicidade', 'interesse', 'otimismo', 'desejo']}, {'tweet': 'O vídeo de hoje é uma volta às origens do canal!\n\nQuem lembra do “Tente Não Rir” e do “APEI”?\n\nEntão…\n\nAssista: https://t.co/iSl2bKhDmV https://t.co/9UkTlsnS6J', 'categoria': 'positivo', 'sentimentos': ['felicidade', 'alegria', 'interesse', 'diversão', 'otimismo', 'desejo']}, {'tweet': 'Pra quem pergunta pq eu parei de usar o Twitter pra dar opinião…\n\nRepostei um texto do mais respeitado crítico de cinema do Brasil, dizendo q concordo com sua visão sobre o filme “Frankenstein”.\n\nTive q ler um desgraçado responder com “Frankenstein é um livro medíocre e vcs só querem pagar de intelectuais”.\n\nLivro medíocre. O livro que inventou a ficção científica. O livro q mudou a literatura. O livro q 200 anos depois continua sendo um dos melhores já escritos, extremamente atual e maravilhoso. Escrito por uma mulher em pleno início do século 19! O livro… Apenas O livro!\n\nEsse é um dos principais motivos que parei de dar opinião nesta bosta, pq todo dia eu ficava lendo gente burra desse nível querendo farmar like. Hoje acabei cedendo, dei uma opinião e lembrei do esgoto q isso aqui virou.', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'repulsa', 'perturbação', 'decepção', 'pessimismo']}, {'tweet': 'Concordo com cada palavra, cada vírgula, cada espaço entre as letras.\n\nE aposto q isso ainda vai ser indicado a “melhor roteiro adaptado”, enfiando uma estaca na alma de Mary Shelley.', 'categoria': 'negativo', 'sentimentos': ['raiva', 'desprezo', 'ironia', 'mágoa']}, {'tweet': 'Mano', 'categoria': 'neutro', 'sentimentos': ['indefinido']}, {'tweet': 'Vídeo extremamente necessário pros dias atuais:\n\nhttps://t.co/WeXOLoWsiW \n\nAproveita, se inscreve no canal do Marcel e manda pros amigos! https://t.co/H1ZY6oPewP', 'categoria': 'positivo', 'sentimentos': ['interesse', 'confiança', 'satisfação', 'desejo']}, {'tweet': 'O vídeo de hoje tá diferente de tudo que a gente já fez em 15 anos de canal!\n\nAssista: https://t.co/MIZEyxQlNF\n\nGostou? Mande o link pra um amigo! https://t.co/s0amH4Q6eC', 'categoria': 'positivo', 'sentimentos': ['interesse', 'confiança', 'otimismo', 'satisfação', 'surpresa']}, {'tweet': 'O vídeo do @brauneoficial do dia em que vimos Cabo Verde ir pra Copa do Mundo ficou ABSURDO!\n\nPra quem viu Netour, esse é um outro ponto de vista muito bom.\n\nAssista: https://t.co/DbVZOJBh1N https://t.co/4K5XTK2mnE', 'categoria': 'positivo', 'sentimentos': ['admiração', 'satisfação', 'interesse', 'diversão', 'alegria']}, {'tweet': 'Absurdo!', 'categoria': 'negativo', 'sentimentos': ['raiva']}, {'tweet': '🏆 PRÊMIO INTERNACIONAL!\nEm uma sátira inspirada em 1984, anunciei minha “candidatura à presidência” — e MUITA gente surtou com isso 🤣\nMas, claro… era uma ação minha com a Audible!\n\nA campanha foi indicada ao OMMA Award, em Nova York!\n\nNossa categoria era “Criatividade em Publicidade Online”, competindo lado a lado com campanhas do McDonald’s 🍟 e de The White Lotus 🏝️\nE lá estávamos nós: Audible + Agência Live + Play9 + Felipe Neto.\n\nE NÓS VENCEMOS! 🥇\n\nMas não parou aí…\nEntre as 58 categorias e centenas de cases no mundo todo, nossa campanha foi eleita o “Best in Show” — ou seja, o MAIOR PRÊMIO DO ANO! 🎖️\n\nMuito, muito, muito orgulho!\nForam +500 milhões de impressões, 2,6 milhões de engajamentos e um aumento de 316% nas visitas ao site da Audible.\n\n🙏 Obrigado @livetheagency, @MediaPost, Play9, Audible… \nE também à @netolaboficial e ao Marcel, que escreveu esse roteiro comigo ❤️', 'categoria': 'positivo', 'sentimentos': ['felicidade', 'alegria', 'diversão', 'admiração', 'confiança', 'satisfação', 'respeito']}, {'tweet': '🔴 ESTÁ NO AR!\n\nNeto ...

# %%
contagem_categorias = Counter(item["categoria"] for item in resultados_sentimentos)
desenhar_grafico_1(contagem_categorias)

# %%
desenhar_grafico_2(resultados_sentimentos)
# Out:
# /tmp/ipython-input-2395048721.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=labels, palette="viridis")

# %%
nuvem_palavras(resultados_sentimentos)

# %%
desenhar_grafico_3(resultados_sentimentos)

# %% [markdown]
# # Conclusão
#
# Fazendo a análise do conteúdo produzido pelos usuários mais influentes da rede social X no Brasil, notamos uma **maioria evidente** com um grau de **positividade** detectado, apesar de ainda ter uma **quantidade elevada** de **negatividade** (cerca de metade da taxa de positividade).
#
# Isso nos mostra que em uma análise inicial, a maioria do conteúdo difundido na rede social tem um grau de sentimento positivo, com essa análise podendo ser expandida das seguintes formas:
#
#
# *   Aumentar o número de contas influentes analisadas
# *   Aumentar o número de tweets por conta analisada
# *   Incluir as respostas dos usuários aos tweets análisados
# *   Incluir graus de positividade e negatividade
# *   Incluir análise baseada em aspectos para diferenciar e identificar os contextos
# *   Fazer modificações no corpus visando uma análise mais acertiva
